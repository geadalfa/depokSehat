# %%
#!git clone --depth=1 https://github.com/geadalfa/twint.git

# %%
#cd twint

# %%
# !pip install . -r requirements.txt
# What version of Python do you have?
import sys

import tensorflow
import pandas as pd
import sklearn as sk
import tensorflow as tf
import ipykernel

check_gpu = len(tf.config.list_physical_devices('GPU'))>0

print(f"Tensor Flow Version: {tf.__version__}")
print(f"Keras Version: {tensorflow.keras.__version__}")
print()
print(f"Python {sys.version}")
print(f"Pandas {pd.__version__}")
print(f"Scikit-Learn {sk.__version__}")
print("GPU is", "available" if check_gpu \
      else "NOT AVAILABLE")
# Out:
# Tensor Flow Version: 2.5.0
# Keras Version: 2.5.0
#
# Python 3.8.10 (default, May 19 2021, 13:12:57) [MSC v.1916 64 bit (AMD64)]
# Pandas 1.2.4
# Scikit-Learn 0.24.2
# GPU is available

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  # Restrict TensorFlow to only allocate 1GB of memory on the first GPU
  try:
    tf.config.experimental.set_virtual_device_configuration(
        gpus[0],
        [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=1024)])
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Virtual devices must be set before GPUs have been initialized
    print(e)
# Out:
# Num GPUs Available:  1
# 1 Physical GPUs, 1 Logical GPUs

# %%
#Crawling
import twint  # import library twint
import nest_asyncio # pip install nest_asyncio 
import json
import time
nest_asyncio.apply() # prevent event loop to be nested
import requests
import re

# Preprocessing
import os
import pandas as pd
pd.set_option('max_colwidth', 5000)
import numpy as np
#from textblob import TextBlob
#from nltk.sentiment.vader import SentimentIntensityAnalyzer
#from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import re
#import nltk
# nltk.download('stopwords')
# nltk.download('punkt')
# nltk.download('vader_lexicon')
#from nltk.corpus import stopwords


# Visualization
import wordcloud
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator # Untuk menampilkan kata-kata yang sering muncul melalui gambar
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt

# Modelling
import tensorflow as tf # library machine learning dari google untuk memproses dataset
from tensorflow.keras.optimizers import RMSprop # mengimport optimizer untuk model
from tensorflow.keras.preprocessing.text import Tokenizer # Mengimport tokenizer untuk preprocessing kata-kata
from tensorflow.keras.preprocessing.sequence import pad_sequences # Mengimport pad_sequences untuk preprocessing kata-kata
from tensorflow.keras.callbacks import ModelCheckpoint # Callback untuk menyimpan model
from tensorflow.keras import regularizers # Library untuk mencegah overfitting pada model
#import imblearn
# from imblearn.under_sampling import (RandomUnderSampler, 
#                                     NearMiss, 
#                                     InstanceHardnessThreshold,
#                                     CondensedNearestNeighbour,
#                                     EditedNearestNeighbours,
#                                     RepeatedEditedNearestNeighbours,
#                                     AllKNN,
#                                     NeighbourhoodCleaningRule,
#                                     OneSidedSelection,
#                                     TomekLinks)

# %%
twi = twint.Config()
#twi.Search = 'Depok OR kesehatan OR rs OR rumah sakit'
#twi.Search = 'Depok OR Kesehatan OR rs'#, 'rumah sakit'#, 'rumah sakit'
#twi.Search = 'Depok', 'puskesmas OR pskms'#, 'rumah sakit'
twi.Search = 'Depok', 'covid OR korona OR corona'
twi.Lang = 'in'
twi.Until = '2021-03-30'
twi.Since = '2020-2-28'
#twi.Geo = "-6.406954, 106.794451,100km"51,100km"
twi.Limit = 100000
Pandas = True
twi.Custom["tweet"] = ["id", "date", "username", "tweet"]
#twi.Output = "kesehatan_fix.csv"
twi.Store_csv = True
#twint.run.Search(twi)

# %%
df = pd.read_csv('kesehatan_fix.csv')

# %%
df.tail()
# Out:
#                         id        date       username  \
# 27578  1234072671723220992  2020-03-01         triarx
# 27579  1233424882475470848  2020-02-28    wonwon_zzzz
# 27580  1233297516193554432  2020-02-28     hab1bull4h
# 27581  1233254169303142401  2020-02-28    menumpahkan
# 27582  1233225553324343297  2020-02-28  wartakotalive
#
#                                                                                                                                                                                                                                                                                           tweet
# 27578                                           Aku : *pas keluar rmh lupa bawa masker* yawdalah yaa dekat gini, belum ada yg positif juga wong depok pinggiran..  Pas di rmh ga enak badan : *panik* *googling segala macam ciri2 korona* *minum vit c* pokoknya tdk boleh sakit* TIDAAAKKKKKK
# 27579                                                                                                                                                                                                          Kalo london bebas corona mah stay aja dulu di sana... Apa mau ke depok sini wkwk
# 27580                                                (🦠) Kalau gini Virus Coronanya bisa kena Virus #corona #coronavirüsü #coronavirüs #coronao #corona🍺 #covid19 #covid #love #cinta #banjir #sayang #rindu #setia #jakarta #bogor #depok #tanggeranh bekasi #puncak…  https://t.co/gkjNJLxiPg
# 27581  Pemerintah mana bisa nanganin wabah corona. Plis sakit yang kita biasa hadapi aja kita kekurangan staff kesehatan dan sarana prasarana. Karena emang kebanyakan warga.  Wabah uler d depok aja gak ada program jelasnya. Warga + komunitas hewan cuma bisa yah pasrah klo ketemu tangkep
# 27582                                         UPDATE Ada 10 Orang Terindikasi Pelaku Prostitusi Diamankan Satpol PP Kota Depok di Sebuah Apartemen  https://t.co/qtz6HLgtic lewat @wartakotalive #TentaraAllah #MyPresidentlsAnIdiot #COVID-19 #BoycottIndia @FeryantoHadi @ladang17 @budimalau

# %% [markdown]
# # Preprocessingg

# %%
# Merubah menjadi huruf kecil
df['cleaned_tweets'] = df['tweet'].apply(lambda x: x.lower())
df.tail()
# Out:
#                         id        date       username  \
# 27578  1234072671723220992  2020-03-01         triarx
# 27579  1233424882475470848  2020-02-28    wonwon_zzzz
# 27580  1233297516193554432  2020-02-28     hab1bull4h
# 27581  1233254169303142401  2020-02-28    menumpahkan
# 27582  1233225553324343297  2020-02-28  wartakotalive
#
#                                                                                                                                                                                                                                                                                           tweet  \
# 27578                                           Aku : *pas keluar rmh lupa bawa masker* yawdalah yaa dekat gini, belum ada yg positif juga wong depok pinggiran..  Pas di rmh ga enak badan : *panik* *googling segala macam ciri2 korona* *minum vit c* pokoknya tdk boleh sakit* TIDAAAKKKKKK
# 27579                                                                                                                                                                                                          Kalo london bebas corona mah stay aja dulu di sana... Apa mau ke depok sini wkwk
# 27580                                                (🦠) Kalau gini Virus Coronanya bisa kena Virus #corona #coronavirüsü #coronavirüs #coronao #corona🍺 #covid19 #covid #love #cinta #banjir #sayang #rindu #setia #jakarta #bogor #depok #tanggeranh bekasi #puncak…  https://t.co/gkjNJLxiPg
# 27581  Pemerintah mana bisa nanganin wabah corona. Plis sakit yang kita biasa hadapi aja kita kekurangan staff kesehatan dan sarana prasarana. Karena emang kebanyakan warga.  Wabah uler d depok aja gak ada program jelasnya. Warga + komunitas hewan cuma bisa yah pasrah klo ketemu tangkep
# 27582                                         UPDATE Ada 10 Orang Terindikasi Pelaku Prostitusi Diamankan Satpol PP Kota Depok di Sebuah Apartemen  https://t.co/qtz6HLgtic lewat @wartakotalive #TentaraAllah #MyPresidentlsAnIdiot #COVID-19 #BoycottIndia @FeryantoHadi @ladang17 @budimalau
#
#                                                                                                                                                                                                                                                                                  cleaned_tweets
# 27578                                           aku : *pas keluar rmh lupa bawa masker* yawdalah yaa dekat gini, belum ada yg positif juga wong depok pinggiran..  pas di rmh ga enak badan : *panik* *googling segala macam ciri2 korona* *minum vit c* pokoknya tdk boleh sakit* tidaaakkkkkk
# 27579                                                                                                                                                                                                          kalo london bebas corona mah stay aja dulu di sana... apa mau ke depok sini wkwk
# 27580                                                (🦠) kalau gini virus coronanya bisa kena virus #corona #coronavirüsü #coronavirüs #coronao #corona🍺 #covid19 #covid #love #cinta #banjir #sayang #rindu #setia #jakarta #bogor #depok #tanggeranh bekasi #puncak…  https://t.co/gkjnjlxipg
# 27581  pemerintah mana bisa nanganin wabah corona. plis sakit yang kita biasa hadapi aja kita kekurangan staff kesehatan dan sarana prasarana. karena emang kebanyakan warga.  wabah uler d depok aja gak ada program jelasnya. warga + komunitas hewan cuma bisa yah pasrah klo ketemu tangkep
# 27582                                         update ada 10 orang terindikasi pelaku prostitusi diamankan satpol pp kota depok di sebuah apartemen  https://t.co/qtz6hlgtic lewat @wartakotalive #tentaraallah #mypresidentlsanidiot #covid-19 #boycottindia @feryantohadi @ladang17 @budimalau

# %%
# Implementasi Regular Expression untuk menghapus simbol dan emoji
def normalisasi(text):
    text = text.encode('ascii', 'replace').decode('ascii') # remove non ASCII (emoticon, chinese word, .etc)
    text = re.sub(r"http\S+", " ", text)
    text = re.sub(r"@\w+", " ", text)
    text = re.sub(r"#\w+", " ", text)
    text = re.sub(r'\W', " ", text)
    text = re.sub(r"\d+", "", text)    
    text = re.sub(r'_', ' ',text)
    text = re.sub(r' +', ' ', text)
    text = re.sub(r"^\s+", '', text)
    #text = text.lstrip()
    return text

df['cleaned_tweets'] = df['cleaned_tweets'].apply(lambda x: normalisasi(x))
df.tail(2)
# Out:
#                         id        date       username  \
# 27581  1233254169303142401  2020-02-28    menumpahkan
# 27582  1233225553324343297  2020-02-28  wartakotalive
#
#                                                                                                                                                                                                                                                                                           tweet  \
# 27581  Pemerintah mana bisa nanganin wabah corona. Plis sakit yang kita biasa hadapi aja kita kekurangan staff kesehatan dan sarana prasarana. Karena emang kebanyakan warga.  Wabah uler d depok aja gak ada program jelasnya. Warga + komunitas hewan cuma bisa yah pasrah klo ketemu tangkep
# 27582                                         UPDATE Ada 10 Orang Terindikasi Pelaku Prostitusi Diamankan Satpol PP Kota Depok di Sebuah Apartemen  https://t.co/qtz6HLgtic lewat @wartakotalive #TentaraAllah #MyPresidentlsAnIdiot #COVID-19 #BoycottIndia @FeryantoHadi @ladang17 @budimalau
#
#                                                                                                                                                                                                                                                                           cleaned_tweets
# 27581  pemerintah mana bisa nanganin wabah corona plis sakit yang kita biasa hadapi aja kita kekurangan staff kesehatan dan sarana prasarana karena emang kebanyakan warga wabah uler d depok aja gak ada program jelasnya warga komunitas hewan cuma bisa yah pasrah klo ketemu tangkep
# 27582                                                                                                                                                                           update ada orang terindikasi pelaku prostitusi diamankan satpol pp kota depok di sebuah apartemen lewat

# %%
# Merubah kata alay menjadi kata baku
dict = {row[0] : row[1] for _, row in pd.read_csv("kbba.txt", delimiter = "\t").iterrows()}

def kbbi(text): 
    token = text.split()
    final_string = ' '.join(str(dict.get(word, word)) for word in token)
    return final_string

df['cleaned_tweets'] = df['cleaned_tweets'].apply(lambda x: kbbi(x))
df.tail(2)
# Out:
#                         id        date       username  \
# 27581  1233254169303142401  2020-02-28    menumpahkan
# 27582  1233225553324343297  2020-02-28  wartakotalive
#
#                                                                                                                                                                                                                                                                                           tweet  \
# 27581  Pemerintah mana bisa nanganin wabah corona. Plis sakit yang kita biasa hadapi aja kita kekurangan staff kesehatan dan sarana prasarana. Karena emang kebanyakan warga.  Wabah uler d depok aja gak ada program jelasnya. Warga + komunitas hewan cuma bisa yah pasrah klo ketemu tangkep
# 27582                                         UPDATE Ada 10 Orang Terindikasi Pelaku Prostitusi Diamankan Satpol PP Kota Depok di Sebuah Apartemen  https://t.co/qtz6HLgtic lewat @wartakotalive #TentaraAllah #MyPresidentlsAnIdiot #COVID-19 #BoycottIndia @FeryantoHadi @ladang17 @budimalau
#
#                                                                                                                                                                                                                                                                                   cleaned_tweets
# 27581  pemerintah mana bisa nanganin wabah corona plis sakit yang kita biasa hadapi saja kita kekurangan staff kesehatan dan sarana prasarana karena memang kebanyakan warga wabah uler di depok saja tidak ada program jelasnya warga komunitas hewan cuma bisa yah pasrah kalau ketemu tangkep
# 27582                                                                                                                                                                          update ada orang terindikasi pelaku prostitusi diamankan satpol pulang pergi kota depok di sebuah apartemen lewat

# %%
# Menghapus stopwords
# def remove_stop_words(text):
#     text = text.split()
#     listStopword =  set(stopwords.words('indonesian'))
#     text = [w for w in text if not w in listStopword]
#     text = " ".join(text)
#     return text

# df['cleaned_tweets'] = df['cleaned_tweets'].apply(lambda x: remove_stop_words(x))
df.tail(2)
# Out:
#                         id        date       username  \
# 27581  1233254169303142401  2020-02-28    menumpahkan
# 27582  1233225553324343297  2020-02-28  wartakotalive
#
#                                                                                                                                                                                                                                                                                           tweet  \
# 27581  Pemerintah mana bisa nanganin wabah corona. Plis sakit yang kita biasa hadapi aja kita kekurangan staff kesehatan dan sarana prasarana. Karena emang kebanyakan warga.  Wabah uler d depok aja gak ada program jelasnya. Warga + komunitas hewan cuma bisa yah pasrah klo ketemu tangkep
# 27582                                         UPDATE Ada 10 Orang Terindikasi Pelaku Prostitusi Diamankan Satpol PP Kota Depok di Sebuah Apartemen  https://t.co/qtz6HLgtic lewat @wartakotalive #TentaraAllah #MyPresidentlsAnIdiot #COVID-19 #BoycottIndia @FeryantoHadi @ladang17 @budimalau
#
#                                                                                                                                                                                                                                                                                   cleaned_tweets
# 27581  pemerintah mana bisa nanganin wabah corona plis sakit yang kita biasa hadapi saja kita kekurangan staff kesehatan dan sarana prasarana karena memang kebanyakan warga wabah uler di depok saja tidak ada program jelasnya warga komunitas hewan cuma bisa yah pasrah kalau ketemu tangkep
# 27582                                                                                                                                                                          update ada orang terindikasi pelaku prostitusi diamankan satpol pulang pergi kota depok di sebuah apartemen lewat

# %%
# Menghapus baris yang mengandung noise
def noise(text): 
    text = text.split()
    listStopword =  ['amp', 'tong', 'fry', 'vcs', 'bahh', 'a', 'wkwkwk', 'c', 'yeey', 'oi', 'pret', 'iya', 'nya', 'sih', 'mbok', 'ku', 'loh', 'lho', 'ah', 'nihh', 'mares', 'openbo', 'ya', 'hah', 'joss', 'deh''rmp', 'v', 'via', 'lha', 'mah', 'xixi']
    text = [w for w in text if not w in listStopword]
    text = " ".join(text)
    return text

df['cleaned_tweets'] = df['cleaned_tweets'].apply(lambda x: noise(x))

# %%
df['cleaned_tweets'] = df['cleaned_tweets'].astype(str)

# %%
df.drop(['id', 'date', 'username'], axis=1, inplace=True)

# %%
df
# Out:
#                                                                                                                                                                                                                                                                                               tweet  \
# 0                                                                                                                     @fathiafifmhsn Negara wkwkwLAND emang suka bikin acara ga jelas buang² anggaran  3 orang kena korona di depok city  pas sembuh dirayain dipikir korona langsung hilang kali🤣🤣
# 1                                                                                                                                  Pemerintah Kota Depok mencatat ada 56 kasus baru Covid-19, 218 pasien pulih, dan sembilan warga meninggal akibat Covid-19 dalam sehari.  https://t.co/XKWJyTVu80
# 2                                 Wakil Wali Kota Depok, Imam Budi Hartono berharap Jawa Barat Culture and Tourism Festival (JaFest) 2021 dapat membantu memulihkan ekonomi di masa pandemi Covid-19. Terutama, pada sektor industri pariwisata.   https://t.co/UlC8uMgZNS  https://t.co/eHHNLaCYos
# 3                                                                                                                                                                                                                                             @hanakubil2 corona ilang gua samperin lu ke depok bil
# 4      Selama Covid-19 Stok Darah Di PMI Kota Depok Tak Pernah Ideal 👇  https://t.co/RRBBk94LpC  #jabarnews #beritalokal #beritahiperlokal #harianjabar #jabartoday #beritajabar #beritajawabarat #jawabarat #jabar #selamcovid19 #stokdarah #pmikotadepok #takpernahideal  https://t.co/fKNGcix0lc
# ...                                                                                                                                                                                                                                                                                             ...
# 27578                                               Aku : *pas keluar rmh lupa bawa masker* yawdalah yaa dekat gini, belum ada yg positif juga wong depok pinggiran..  Pas di rmh ga enak badan : *panik* *googling segala macam ciri2 korona* *minum vit c* pokoknya tdk boleh sakit* TIDAAAKKKKKK
# 27579                                                                                                                                                                                                              Kalo london bebas corona mah stay aja dulu di sana... Apa mau ke depok sini wkwk
# 27580                                                    (🦠) Kalau gini Virus Coronanya bisa kena Virus #corona #coronavirüsü #coronavirüs #coronao #corona🍺 #covid19 #covid #love #cinta #banjir #sayang #rindu #setia #jakarta #bogor #depok #tanggeranh bekasi #puncak…  https://t.co/gkjNJLxiPg
# 27581      Pemerintah mana bisa nanganin wabah corona. Plis sakit yang kita biasa hadapi aja kita kekurangan staff kesehatan dan sarana prasarana. Karena emang kebanyakan warga.  Wabah uler d depok aja gak ada program jelasnya. Warga + komunitas hewan cuma bisa yah pasrah klo ketemu tangkep
# 27582                                             UPDATE Ada 10 Orang Terindikasi Pelaku Prostitusi Diamankan Satpol PP Kota Depok di Sebuah Apartemen  https://t.co/qtz6HLgtic lewat @wartakotalive #TentaraAllah #MyPresidentlsAnIdiot #COVID-19 #BoycottIndia @FeryantoHadi @ladang17 @budimalau
#
#                                                                                                                                                                                                                                                                                   cleaned_tweets
# 0                                                                                                                                    negara wkwkwland memang suka bikin acara tidak jelas buang anggaran orang kena korona di depok city pas sembuh dirayain dipikir korona langsung hilang kali
# 1                                                                                                                                                                        pemerintah kota depok mencatat ada kasus baru covid pasien pulih dan sembilan warga meninggal akibat covid dalam sehari
# 2                                                                                               wakil wali kota depok imam budi hartono berharap jawa barat culture and tourism festival jafest dapat membantu memulihkan ekonomi di masa pandemi covid terutama pada sektor industri pariwisata
# 3                                                                                                                                                                                                                                                  corona hilang saya samperin kamu ke depok bil
# 4                                                                                                                                                                                                                                   selama covid stok darah di pmi kota depok tidak pernah ideal
# ...                                                                                                                                                                                                                                                                                          ...
# 27578                                                   aku pas keluar rumah lupa bawa masker yawdalah yaa dekat begini belum ada yang positif juga wong depok pinggiran pas di rumah tidak enak badan panik googling segala macam ciri korona minum vit pokoknya tidak boleh sakit tidaaakkkkkk
# 27579                                                                                                                                                                                                             kalau london bebas corona stay saja dulu di sana apa mau ke depok sini tertawa
# 27580                                                                                                                                                                                                                                    kalau begini virus coronanya bisa kena virus s s bekasi
# 27581  pemerintah mana bisa nanganin wabah corona plis sakit yang kita biasa hadapi saja kita kekurangan staff kesehatan dan sarana prasarana karena memang kebanyakan warga wabah uler di depok saja tidak ada program jelasnya warga komunitas hewan cuma bisa yah pasrah kalau ketemu tangkep
# 27582                                                                                                                                                                          update ada orang terindikasi pelaku prostitusi diamankan satpol pulang pergi kota depok di sebuah apartemen lewat
#
# [27583 rows x 2 columns]

# %%
'''import spacy
nlp = spacy.blank('id')
from spacy.lang.id import Indonesian
nlp_id = Indonesian()

df["stemmed_tweets"] = df["cleaned_tweets"].apply(lambda x: " ".join([y.lemma_ for y in nlp_id(x)]))'''
#df["stemmed_tweets"] = df["cleaned_tweets"].apply(lambda row: " ".join([w.lemma_ for w in nlp(row)]))


# def Stemming(tweet):
#     token = nltk.word_tokenize(tweet)
#     stem_kalimat = []
#     for k in token:
#         factory = StemmerFactory()
#         stemmer = factory.create_stemmer()
#         stem_kata = stemmer.stem(k.encode('ascii','ignore'))
#         stem_kalimat.append(stem_kata)

#     stem_kalimat_str = ' '.join(stem_kalimat)
#     return stem_kalimat_str

# menghilangkan semua imbuhan kata dalam kalimat
'''def steamming(text):
    factory = StemmerFactory()
    stemmer = factory.create_stemmer()
    split = text.split()
    hasil = [stemmer.stem(token) for token in split]
    hasil = " ".join(hasil)
    return hasil

df['stemmed_tweets'] = df['cleaned_tweets'].apply(lambda x: steamming(x))'''

#df['cleaned_tweets'] = df['cleaned_tweets'].apply(lambda x: Stemming(x))
# Out:
# 'def steamming(text):\n    factory = StemmerFactory()\n    stemmer = factory.create_stemmer()\n    split = text.split()\n    hasil = [stemmer.stem(token) for token in split]\n    hasil = " ".join(hasil)\n    return hasil\n\ndf[\'stemmed_tweets\'] = df[\'cleaned_tweets\'].apply(lambda x: steamming(x))'

# %%
df1 = df.copy()
df1.drop(['tweet'], axis=1, inplace=True)
df1.drop_duplicates(keep=False,inplace=True)
df1.reset_index(drop=True, inplace=True)

# %%
len(df1)
df1.tail(2)
# Out:
#                                                                                                                                                                                                                                                                                   cleaned_tweets
# 22177  pemerintah mana bisa nanganin wabah corona plis sakit yang kita biasa hadapi saja kita kekurangan staff kesehatan dan sarana prasarana karena memang kebanyakan warga wabah uler di depok saja tidak ada program jelasnya warga komunitas hewan cuma bisa yah pasrah kalau ketemu tangkep
# 22178                                                                                                                                                                          update ada orang terindikasi pelaku prostitusi diamankan satpol pulang pergi kota depok di sebuah apartemen lewat

# %%
#df.to_excel("output.xlsx")

# %% [markdown]
# # Visualisasi Kata

# %%
import matplotlib.pyplot
import seaborn as sns

comment_words=''

for val in df.cleaned_tweets:  
    # merubah val menjadi string
    val = str(val)
  
    # memisahkan variabel val per kata
    tokens = val.split() 
      
    # Mengonversi variabel val menjadi huruf kecil
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower() 
      
    comment_words += " ".join(tokens)+" "

# %%
wordcloud1 = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                stopwords = STOPWORDS, 
                min_font_size = 10).generate(comment_words)
plt.figure(figsize = (10,10), facecolor = None) 
plt.imshow(wordcloud1) 
plt.axis("off") 
plt.title("Kata yang Paling Banyak Muncul", fontsize = 37)
plt.tight_layout(pad = 1) 
  
plt.show()

# %%
# Mengambil gambar dari website
Mask = np.array(Image.open(requests.get('http://clipart-library.com/images_k/animal-silhouette-painting/animal-silhouette-painting-7.png', stream = True).raw))

# Menggunakan warna dari gambar yang telah diambil
image_colors = ImageColorGenerator(Mask)

# Menggunakan fungsi wordcloud dan memasukkan ke dalam variabel wc 
wc = WordCloud(background_color = 'white', height = 3000, width = 5000, mask = Mask).generate(comment_words)

# Menentukan besarnya gambar
plt.figure(figsize = (20, 30))

# Menampilkan gambar sesuai dengan warna yang telah ada di dalam gambar
plt.imshow(wc.recolor(color_func = image_colors), interpolation = "hamming")

plt.axis('off')
plt.show()

# %%
with open('sentimentword.txt', 'r') as data:
    for line in data :
        line.rstrip()
    plaintext = data.read()
    
plaintext = plaintext.replace(' ', ',')

with open('kata_sentimen_negatif.txt', 'r',encoding='utf-8-sig') as data:
    plaintext1 = data.read()
    plaintext1 = plaintext1.rstrip()
    
with open('kata_sentimen_positif.txt', 'r',encoding='utf-8-sig') as data:
    plaintext2 = data.read()
    plaintext2 = plaintext2.rstrip()

with open("kata_sentimen.txt", 'w') as f:
    f.write(plaintext + '\n')
    
with open("kata_sentimen_fix.txt", 'w') as f:
    f.write(plaintext + '\n')
    f.write(plaintext1 + '\n')
    f.write(plaintext2 + '\n')

with open("kata_sentimen_fix.txt", 'r') as f:
    sentifix = f.read()
sentifix = sentifix.replace(',', '\t')

with open("sentifix.txt", 'w') as f:
    f.write(sentifix + '\n')

# %%
kamus_sentimen = 'sentifix.txt'

def sentiment_dict(kamus_sentimen):
    ''' (file) -> dictionary
This method should take your sentiment file
and create a dictionary in the form {word: value}
'''    
    kamus = open(kamus_sentimen)
    scores = {} # initialize an empty dictionary
    for line in kamus:
        term, score = line.split("\t") # The file is comma-delimited. 
        scores[term] = int(score) # Convert the score to an integer.

    return scores

# %%
import codecs

doc = codecs.open('sentifix.txt','rU','UTF-8') #open for reading with "universal" type set

kamus = pd.read_csv(doc, sep='\t', header=None)
kamus
# Out:
#                  0  1
# 0             kali -1
# 1         terbatas -3
# 2      penyebabnya -4
# 3          positif -1
# 4           korona -2
# ...            ... ..
# 10230    melarikan  3
# 10231      vakansi  3
# 10232      spesial  4
# 10233       asrama  3
# 10234     orisinal  3
#
# [10235 rows x 2 columns]

# %%
kamus = kamus.set_index(0).T.to_dict('records')
dct = {}
for item in kamus:
    dct.update(item)

#dct
# Out:
# ipykernel_launcher:1: UserWarning: DataFrame columns are not unique, some columns will be omitted.

# %%
#type(dct['covid'])

# %%
data = df1['cleaned_tweets']
skor = []

for line in data:
    tweet_word = line.split()
    #sent_score is a variable which will take care of word strength / word weightage
    sum_score = 0
    sent_score = 0
    l = len(tweet_word)
    #print(l)
    
    for word in tweet_word:
        word = word.rstrip('?:!.,;"!@')
        word = word.replace("\n", "")

        if word in dct.keys():
            sum_score += int(dct[word])\
    
    skor.append(sum_score)


print(len(skor))
# print(tweet_word)
#print(l)
# Out:
# 22179

# %%
print(skor[10])
# Out:
# 1

# %%
# data = df1['cleaned_tweets']
# skor = []
# #for index in range(len(df1)):
#     #tweet_word = tweets[index].split(',')
# for line in data:
#     tweet_word = line.split()
#     #sent_score is a variable which will take care of word strength / word weightage 
#     sent_score = 0
#     for word in tweet_word:
#         word = word.rstrip('?:!.,;"!@')
#         word = word.replace("\n", "")

#         if word in dct.keys():
#             sent_score = sent_score + int(dct[word])
#             #break
#             skor.append(sent_score)
#             #print(sent_score)
#             break

#         else:
#             sent_score = sent_score
#             #break
#             skor.append(sent_score)
#             #print(sent_score)
#             break
#print(len(sent_score))

#     if int(sent_score) > 0:
#         print(tweets[index])
#         if (int(sent_score) > 0.7):
#             print(sent_score) 
#             print('Highly Positive Sentiment')
#         else:
#             print(sent_score)
#             print('Positive Sentiment')


#     if int(sent_score) < 0:
#         print(tweets[index])
#         if int(sent_score) < -0.7:
#             print(sent_score)
#             print('Highly Negative Sentiment')
#         else:
#             print(sent_score)
#             print('Negative Sentiment')


#     if int(sent_score) == 0:
#         print(tweets[index])
#         print('Neutral Sentiment')
print(len(skor))
# Out:
# 22179

# %%
#skor
df1['nilai'] = skor
df1.tail(10)
# Out:
#                                                                                                                                                                                                                                                                                   cleaned_tweets  \
# 22169                                                                                                                                                                                       menurut menkes terawan agus putranto dua orang yang positive terjangkit virus corona beradomisili di
# 22170                                                                                                                                                                                                                                                   terawan orang warga depok positip corona
# 22171                                                                                           wawancara konfirmasi warga jakarta yang kena corona wartawan bagaimana pak dari mana virusnya datang kok bisa tiba sampai ke depok ingin aku keplak juga wartawan yang bertanya kayak begini ini
# 22172                                                                                                                                                                                                         lagi makan di parhi and then suddenly corona alert di indo dan katanya orang depok
# 22173                                                                             pemerintah segera umumkan ada temuan penderita covid ibu dan anak dirawat di rs sulianti saroso pemeriksaan dan penelusuran sudah dilakukan di kediaman pasien di depok tunggu laporan dan pengumuman resminya
# 22174                                                   aku pas keluar rumah lupa bawa masker yawdalah yaa dekat begini belum ada yang positif juga wong depok pinggiran pas di rumah tidak enak badan panik googling segala macam ciri korona minum vit pokoknya tidak boleh sakit tidaaakkkkkk
# 22175                                                                                                                                                                                                             kalau london bebas corona stay saja dulu di sana apa mau ke depok sini tertawa
# 22176                                                                                                                                                                                                                                    kalau begini virus coronanya bisa kena virus s s bekasi
# 22177  pemerintah mana bisa nanganin wabah corona plis sakit yang kita biasa hadapi saja kita kekurangan staff kesehatan dan sarana prasarana karena memang kebanyakan warga wabah uler di depok saja tidak ada program jelasnya warga komunitas hewan cuma bisa yah pasrah kalau ketemu tangkep
# 22178                                                                                                                                                                          update ada orang terindikasi pelaku prostitusi diamankan satpol pulang pergi kota depok di sebuah apartemen lewat
#
#        nilai
# 22169     -2
# 22170     -1
# 22171    -11
# 22172     -7
# 22173      2
# 22174     -6
# 22175     -2
# 22176     -5
# 22177    -23
# 22178      7

# %%
def f(row):
    if row['nilai'] >= 3 :
        val = 'positif'
    elif row['nilai'] <= -2 :
        val = 'negatif'
    else:
        val = 'netral'
    return val

df1['sentimen'] = df1.apply(f, axis = 1)
df1
# Out:
#                                                                                                                                                                                                                                                                                   cleaned_tweets  \
# 0                                                                                                                                    negara wkwkwland memang suka bikin acara tidak jelas buang anggaran orang kena korona di depok city pas sembuh dirayain dipikir korona langsung hilang kali
# 1                                                                                                                                                                        pemerintah kota depok mencatat ada kasus baru covid pasien pulih dan sembilan warga meninggal akibat covid dalam sehari
# 2                                                                                               wakil wali kota depok imam budi hartono berharap jawa barat culture and tourism festival jafest dapat membantu memulihkan ekonomi di masa pandemi covid terutama pada sektor industri pariwisata
# 3                                                                                                                                                                                                                                                  corona hilang saya samperin kamu ke depok bil
# 4                                                                                                                                                                                                                                   selama covid stok darah di pmi kota depok tidak pernah ideal
# ...                                                                                                                                                                                                                                                                                          ...
# 22174                                                   aku pas keluar rumah lupa bawa masker yawdalah yaa dekat begini belum ada yang positif juga wong depok pinggiran pas di rumah tidak enak badan panik googling segala macam ciri korona minum vit pokoknya tidak boleh sakit tidaaakkkkkk
# 22175                                                                                                                                                                                                             kalau london bebas corona stay saja dulu di sana apa mau ke depok sini tertawa
# 22176                                                                                                                                                                                                                                    kalau begini virus coronanya bisa kena virus s s bekasi
# 22177  pemerintah mana bisa nanganin wabah corona plis sakit yang kita biasa hadapi saja kita kekurangan staff kesehatan dan sarana prasarana karena memang kebanyakan warga wabah uler di depok saja tidak ada program jelasnya warga komunitas hewan cuma bisa yah pasrah kalau ketemu tangkep
# 22178                                                                                                                                                                          update ada orang terindikasi pelaku prostitusi diamankan satpol pulang pergi kota depok di sebuah apartemen lewat
#
#        nilai sentimen
# 0         -1   netral
# 1          3  positif
# 2          5  positif
# 3         -8  negatif
# 4         -3  negatif
# ...      ...      ...
# 22174     -6  negatif
# 22175     -2  negatif
# 22176     -5  negatif
# 22177    -23  negatif
# 22178      7  positif
#
# [22179 rows x 3 columns]

# %%
# df45=pd.read_csv('hasil_label.csv', index_col=0)
# df45

# %%
df1 = pd.read_csv("hasil_label.csv", index_col=0)

#df1.to_csv("hasil_label.csv")

# %%
#df1.loc[df1['sentimen'] == 'positif'].head()
positif1=df1.loc[df1['nilai'] > 15].head()
negatif1 = df1.loc[df1['nilai'] < -25].head()
netral1 = df1.loc[df1['nilai'] == -1].head()
headings1 = positif1.columns
headings1
#netral1
#df1.loc[df1['sentimen'].isin(some_values)]
# Out:
# Index(['cleaned_tweets', 'nilai', 'sentimen'], dtype='object')

# %%
# tuples = [tuple(x) for x in positif1.values]
# tuples
#data = (
#         ("Aku bisa membuatmu", "15", "Positif"),
#         ("Covid membunuhmu", "-20", "Negatif")
#     )
# print(type(data))

# %%
senti_count = df1['sentimen'].value_counts()
print(type(senti_count))
print(senti_count)
# Out:
# <class 'pandas.core.series.Series'>
# negatif    10586
# positif     6647
# netral      4946
# Name: sentimen, dtype: int64

# %%
senti_count2=list(zip(str(senti_count),str(senti_count.index)))
senti_count2=tuple(zip(senti_count,senti_count.index))
kolom=[(sub[1], sub[0]) for sub in senti_count2]
kolom
# Out:
# [('negatif', 10586), ('positif', 6647), ('netral', 4946)]

# %%
labels=[]
values=[]
for row in kolom:
    labels.append(row[0])
    values.append(row[1])
print(labels)
print(values)
# Out:
# ['negatif', 'positif', 'netral']
# [10586, 6647, 4946]

# %%
sns.set(font_scale=1.4)
senti_count.plot(kind='pie', figsize=(8, 10))#, rot=0)
plt.title("Sentimen", y=1.02);

# %%
my_labels = 'Negatif','Positif','Netral'
my_colors = ['orange','lightblue','silver']
my_explode = (0.1, 0.1, 0)
plt.pie(senti_count, labels=my_labels, autopct='%1.1f%%', startangle=15, shadow = True, colors=my_colors, explode=my_explode)
plt.title('Sentimen Tweet')
plt.axis('equal')
plt.show()

# %%
# Menggunakan one hot encoding untuk merubah kolom sentiment menjadi kategorikal
sentimen = pd.get_dummies(df1.sentimen,prefix='sentimen')
df1 = pd.concat([df1, sentimen], axis=1)
df1 = df1.drop(columns='nilai')
df1
# Out:
#                                                                                                                                                                                                                                                                                   cleaned_tweets  \
# 0                                                                                                                                    negara wkwkwland memang suka bikin acara tidak jelas buang anggaran orang kena korona di depok city pas sembuh dirayain dipikir korona langsung hilang kali
# 1                                                                                                                                                                        pemerintah kota depok mencatat ada kasus baru covid pasien pulih dan sembilan warga meninggal akibat covid dalam sehari
# 2                                                                                               wakil wali kota depok imam budi hartono berharap jawa barat culture and tourism festival jafest dapat membantu memulihkan ekonomi di masa pandemi covid terutama pada sektor industri pariwisata
# 3                                                                                                                                                                                                                                                  corona hilang saya samperin kamu ke depok bil
# 4                                                                                                                                                                                                                                   selama covid stok darah di pmi kota depok tidak pernah ideal
# ...                                                                                                                                                                                                                                                                                          ...
# 22174                                                   aku pas keluar rumah lupa bawa masker yawdalah yaa dekat begini belum ada yang positif juga wong depok pinggiran pas di rumah tidak enak badan panik googling segala macam ciri korona minum vit pokoknya tidak boleh sakit tidaaakkkkkk
# 22175                                                                                                                                                                                                             kalau london bebas corona stay saja dulu di sana apa mau ke depok sini tertawa
# 22176                                                                                                                                                                                                                                    kalau begini virus coronanya bisa kena virus s s bekasi
# 22177  pemerintah mana bisa nanganin wabah corona plis sakit yang kita biasa hadapi saja kita kekurangan staff kesehatan dan sarana prasarana karena memang kebanyakan warga wabah uler di depok saja tidak ada program jelasnya warga komunitas hewan cuma bisa yah pasrah kalau ketemu tangkep
# 22178                                                                                                                                                                          update ada orang terindikasi pelaku prostitusi diamankan satpol pulang pergi kota depok di sebuah apartemen lewat
#
#       sentimen  sentimen_negatif  sentimen_netral  sentimen_positif
# 0       netral                 0                1                 0
# 1      positif                 0                0                 1
# 2      positif                 0                0                 1
# 3      negatif                 1                0                 0
# 4      negatif                 1                0                 0
# ...        ...               ...              ...               ...
# 22174  negatif                 1                0                 0
# 22175  negatif                 1                0                 0
# 22176  negatif                 1                0                 0
# 22177  negatif                 1                0                 0
# 22178  positif                 0                0                 1
#
# [22179 rows x 5 columns]

# %%
# Agar dapat diproses oleh model, kita perlu mengubah nilai-nilai dari dataframe ke dalam tipe data numpy array menggunakan atribut values.
tweet_sentimen = df1['cleaned_tweets'].values
label = df1[['sentimen_negatif', 'sentimen_netral',
       'sentimen_positif']].values

# %% [markdown]
# # Data Splitting

# %%
# Membagi data menjadi 90% data train dan 10% data test
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(tweet_sentimen, label, test_size=0.1)

# %%
# Memasukkan fungsi tokenizer yang didalamnya terdapat parameter untuk menyimpan 6500 kata yang sering muncul
tokenizer = Tokenizer(num_words=6500, oov_token='-')
tokenizer.fit_on_texts(x_train) 
tokenizer.fit_on_texts(x_test)

# Memasukkan data train dan test ke dalam sequence
sekuens_latih = tokenizer.texts_to_sequences(x_train)
sekuens_test = tokenizer.texts_to_sequences(x_test)

# Menggunakan padding agar sequence menjadi sama panjang
padded_latih = pad_sequences(sekuens_latih) 
padded_test = pad_sequences(sekuens_test)

# %%
tokenIndexKata=tokenizer.word_index
print(tokenIndexKata)
# Out:
# {'-': 1, 'depok': 2, 'di': 3, 'corona': 4, 'covid': 5, 'yang': 6, 'kota': 7, 'dan': 8, 'virus': 9, 'tidak': 10, 'positif': 11, 'warga': 12, 'ada': 13, 'ini': 14, 'orang': 15, 'dari': 16, 'sudah': 17, 'saya': 18, 'ke': 19, 'pasien': 20, 'untuk': 21, 'pemerintah': 22, 'kasus': 23, 'itu': 24, 'dengan': 25, 'saja': 26, 'jakarta': 27, 'jadi': 28, 'rumah': 29, 'karena': 30, 'kena': 31, 'indonesia': 32, 'kalau': 33, 'juga': 34, 'lagi': 35, 'bisa': 36, 'barat': 37, 'jawa': 38, 'tapi': 39, 'dalam': 40, 'dua': 41, 'hari': 42, 'bogor': 43, 'wali': 44, 'penyebaran': 45, 'sama': 46, 'masih': 47, 'korona': 48, 'daerah': 49, 'pada': 50, 'apa': 51, 'terus': 52, 'masker': 53, 'mau': 54, 'kesehatan': 55, 'bekasi': 56, 'rs': 57, 'baru': 58, 'pertama': 59, 'news': 60, 'penanganan': 61, 'sampai': 62, 'kita': 63, 'banyak': 64, 'kamu': 65, 'akan': 66, 'masuk': 67, 'sembuh': 68, 'pandemi': 69, 'atau': 70, 'saat': 71, 'belum': 72, 'banget': 73, 'masyarakat': 74, 'aku': 75, 'jangan': 76, 'tinggal': 77, 'sakit': 78, 'zona': 79, 'sekarang': 80, 'jabar': 81, 'psbb': 82, 'berita': 83, 'wilayah': 84, 'merah': 85, 'semua': 86, 'setelah': 87, 'lebih': 88, 'satu': 89, 'meninggal': 90, 'semoga': 91, 'harus': 92, 'deh': 93, 'teman': 94, 'kan': 95, 'tahu': 96, 'anak': 97, 'pak': 98, 'informasi': 99, 'seperti': 100, 'takut': 101, 'bukan': 102, 'idris': 103, 'begitu': 104, 'sebagai': 105, 'gubernur': 106, 'tempat': 107, 'vaksin': 108, 'mulai': 109, 'buat': 110, 'wni': 111, 'dia': 112, 'terkait': 113, 'bahkan': 114, 'walikota': 115, 'lain': 116, 'kepada': 117, 'keluarga': 118, 'bagaimana': 119, 'memang': 120, 'tetap': 121, 'langsung': 122, 'lewat': 123, 'jam': 124, 'cegah': 125, 'kemarin': 126, 'protokol': 127, 'terinfeksi': 128, 'menjadi': 129, 'kepala': 130, 'pakai': 131, 'wabah': 132, 'pencegahan': 133, 'pas': 134, 'cuma': 135, 'malam': 136, 'tugas': 137, 'dki': 138, 'ridwan': 139, 'melakukan': 140, 'kamil': 141, 'jepang': 142, 'tersebut': 143, 'dulu': 144, 'pulang': 145, 'panik': 146, 'bantuan': 147, 'ibu': 148, 'gugus': 149, 'hingga': 150, 'dapat': 151, 'jalan': 152, 'oleh': 153, 'begini': 154, 'selama': 155, 'terjangkit': 156, 'isolasi': 157, 'terkena': 158, 'test': 159, 'salah': 160, 'tahun': 161, 'bertambah': 162, 'terdampak': 163, 'kenapa': 164, 'data': 165, 'agar': 166, 'jumlah': 167, 'mereka': 168, 'rsud': 169, 'penularan': 170, 'bersama': 171, 'mana': 172, 'kami': 173, 'dinyatakan': 174, 'awal': 175, 'terpapar': 176, 'kembali': 177, 'telah': 178, 'kelurahan': 179, 'kecamatan': 180, 'dekat': 181, 'bilang': 182, 'maret': 183, 'benar': 184, 'baik': 185, 'kabupaten': 186, 'si': 187, 'tentang': 188, 'bagi': 189, 'lalu': 190, 'vaksinasi': 191, 'kali': 192, 'sementara': 193, 'rapid': 194, 'soal': 195, 'kerja': 196, 'siaga': 197, 'jaga': 198, 'sedang': 199, 'sehat': 200, 'sempat': 201, 'tertular': 202, 'sekolah': 203, 'kegiatan': 204, 'korban': 205, 'mohammad': 206, 'kasih': 207, 'sosial': 208, 'bahan': 209, 'secara': 210, 'selalu': 211, 'update': 212, 'hanya': 213, 'baca': 214, 'adalah': 215, 'kini': 216, 'asal': 217, 'the': 218, 'presiden': 219, 'waspada': 220, 'terima': 221, 'bikin': 222, 'kantor': 223, 'satgas': 224, 'padahal': 225, 'tenaga': 226, 'lah': 227, 'sebelum': 228, 'gara': 229, 'medis': 230, 'mencegah': 231, 'puskesmas': 232, 'pasar': 233, 'ui': 234, 'kok': 235, 'cepat': 236, 'tangerang': 237, 'negara': 238, 'dilakukan': 239, 'begal': 240, 'tanggal': 241, 'pusat': 242, 'ramai': 243, 'menkes': 244, 'allah': 245, 'tes': 246, 'masa': 247, 'kabar': 248, 'minggu': 249, 'pokok': 250, 'waktu': 251, 'sembilan': 252, 'keluar': 253, 'naik': 254, 'krl': 255, 'in': 256, 'eh': 257, 'rt': 258, 'bulan': 259, 'minta': 260, 'habis': 261, 'stay': 262, 'melaksanakan': 263, 'apakah': 264, 'percepatan': 265, 'ternyata': 266, 'perlu': 267, 'wakil': 268, 'hal': 269, 'dirawat': 270, 'rw': 271, 'tengah': 272, 'kata': 273, 'besar': 274, 'swab': 275, 'akibat': 276, 'kondisi': 277, 'pemilihan': 278, 'sebanyak': 279, 'lihat': 280, 'warganya': 281, 'para': 282, 'usai': 283, 'in ...

# %%
sampel_data=['selama covid stok darah di pmi kota depok tidak pernah ideal',
            'vial vaksin covid tahap kedua kembali tiba di depok']
tokenizer2 = Tokenizer(num_words=100, oov_token='-')
tokenizer2.fit_on_texts(sampel_data)
tokenIndexKata=tokenizer2.word_index

sekuens_sampel = tokenizer2.texts_to_sequences(sampel_data)

padded_sampel = pad_sequences(sekuens_sampel)

print(tokenIndexKata)
print(sekuens_sampel)
print(padded_sampel)
# Out:
# {'-': 1, 'covid': 2, 'di': 3, 'depok': 4, 'selama': 5, 'stok': 6, 'darah': 7, 'pmi': 8, 'kota': 9, 'tidak': 10, 'pernah': 11, 'ideal': 12, 'vial': 13, 'vaksin': 14, 'tahap': 15, 'kedua': 16, 'kembali': 17, 'tiba': 18}
# [[5, 2, 6, 7, 3, 8, 9, 4, 10, 11, 12], [13, 14, 2, 15, 16, 17, 18, 3, 4]]
# [[ 5  2  6  7  3  8  9  4 10 11 12]
#  [ 0  0 13 14  2 15 16 17 18  3  4]]

# %%
import pickle5 as pickle
with open('tokenizer2.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# # Modelling

# %%
# Membuat kelas dan fungsi agar proses training berhenti saat akurasi validasi model telah mencapai 92%
class myCallBack(tf.keras.callbacks.Callback):    
    def on_epoch_end(self, epoch, logs={}):
        if(logs.get('val_accuracy') >= 0.85):
            print("\nAkurasi validasi telah mencapai > 85%!")
            self.model.stop_training = True
myCallBack = myCallBack()

# %%
# Fungsi untuk menyimpan model "C:\Users\Alfa\Program Skripsi\kesehatan_fix_blom_fix.csv"
save_direc = os.path.join(os.getcwd(), 'C:/Users/Alfa/Program Skripsi/')

model_name = 'geaNlp_weight_model2.h5'
model_name2 = 'geaNlp_weight_model3.h5'

# Membuat directory untuk menyimpan model
if not os.path.isdir(save_direc):
    os.makedirs(save_direc)

# Menggabungkan directory dengan model
modelpath = os.path.join(save_direc, model_name2)

checkpoint = ModelCheckpoint(filepath = modelpath, verbose = 2, monitor='val_accuracy',
                             save_best_only = True, save_weights_only = True)#,save_freq=1)

# %%
# Membuat model Sequential dengan Bidirectional LSTM
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(6500, 32), # 6500 input & 32 layer embedding
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64,  return_sequences=True)), # 64 layer LSTM
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)), # 32 layer LSTM
    #tf.keras.layers.Dropout(0.1),
    tf.keras.layers.Dense(128, activation='relu'), # Menambah layer dan menggunakan relu sebagai fungsi aktivasi
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(512, kernel_regularizer=regularizers.l2(0.001), activation='relu'), #kernel_regularizer=regularizers.l2(0.0001),
    tf.keras.layers.Dropout(0.5), # Menggunakan dropout agar model tidak overfitting
    tf.keras.layers.Dense(3, activation='softmax') # Outputnya adalah 3 dan karena kategorikal menggunakan aktivasi softmax
])

model.summary() # Melihat shape dan parameter model
model.compile(loss='categorical_crossentropy', optimizer=RMSprop(learning_rate=0.0001),metrics=['accuracy']) # Menggunakan optimizer RMSprop dengan learning rate 0.0001
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, None, 32)          208000
# _________________________________________________________________
# bidirectional_8 (Bidirection (None, None, 128)         49664
# _________________________________________________________________
# bidirectional_9 (Bidirection (None, 64)                41216
# _________________________________________________________________
# dense_16 (Dense)             (None, 128)               8320
# _________________________________________________________________
# dense_17 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_18 (Dense)             (None, 512)               66048
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 3)                 1539
# =================================================================
# Total params: 391,299
# Trainable params: 391,299
# Non-trainable params: 0
# _________________________________________________________________

# %%
#batch_size = 16
history = model.fit(padded_latih, y_train, validation_data=(padded_test, y_test), epochs=350,#batch_size=batch_size,
                    steps_per_epoch= 30, callbacks=[myCallBack, checkpoint], verbose=2)
# Out:
# Epoch 1/350
# 30/30 - 9s - loss: 1.2783 - accuracy: 0.4682 - val_loss: 1.2513 - val_accuracy: 0.4815
#
# Epoch 00001: val_accuracy improved from -inf to 0.48151, saving model to C:/Users/Alfa/Program Skripsi\geaNlp_weight_model2.h5
# Epoch 2/350
# 30/30 - 2s - loss: 1.2302 - accuracy: 0.4768 - val_loss: 1.2133 - val_accuracy: 0.4815
#
# Epoch 00002: val_accuracy did not improve from 0.48151
# Epoch 3/350
# 30/30 - 2s - loss: 1.1982 - accuracy: 0.4768 - val_loss: 1.1810 - val_accuracy: 0.4815
#
# Epoch 00003: val_accuracy did not improve from 0.48151
# Epoch 4/350
# 30/30 - 2s - loss: 1.1678 - accuracy: 0.4802 - val_loss: 1.1561 - val_accuracy: 0.4865
#
# Epoch 00004: val_accuracy improved from 0.48151 to 0.48647, saving model to C:/Users/Alfa/Program Skripsi\geaNlp_weight_model2.h5
# Epoch 5/350
# 30/30 - 2s - loss: 1.1461 - accuracy: 0.4902 - val_loss: 1.1366 - val_accuracy: 0.4923
#
# Epoch 00005: val_accuracy improved from 0.48647 to 0.49234, saving model to C:/Users/Alfa/Program Skripsi\geaNlp_weight_model2.h5
# Epoch 6/350
# 30/30 - 2s - loss: 1.1234 - accuracy: 0.4974 - val_loss: 1.1110 - val_accuracy: 0.5063
#
# Epoch 00006: val_accuracy improved from 0.49234 to 0.50631, saving model to C:/Users/Alfa/Program Skripsi\geaNlp_weight_model2.h5
# Epoch 7/350
# 30/30 - 2s - loss: 1.0936 - accuracy: 0.5111 - val_loss: 1.0760 - val_accuracy: 0.5207
#
# Epoch 00007: val_accuracy improved from 0.50631 to 0.52074, saving model to C:/Users/Alfa/Program Skripsi\geaNlp_weight_model2.h5
# Epoch 8/350
# 30/30 - 2s - loss: 1.0498 - accuracy: 0.5355 - val_loss: 1.0246 - val_accuracy: 0.5613
#
# Epoch 00008: val_accuracy improved from 0.52074 to 0.56132, saving model to C:/Users/Alfa/Program Skripsi\geaNlp_weight_model2.h5
# Epoch 9/350
# 30/30 - 2s - loss: 0.9880 - accuracy: 0.5815 - val_loss: 0.9652 - val_accuracy: 0.6055
#
# Epoch 00009: val_accuracy improved from 0.56132 to 0.60550, saving model to C:/Users/Alfa/Program Skripsi\geaNlp_weight_model2.h5
# Epoch 10/350
# 30/30 - 2s - loss: 0.9208 - accuracy: 0.6233 - val_loss: 0.8985 - val_accuracy: 0.6425
#
# Epoch 00010: val_accuracy improved from 0.60550 to 0.64247, saving model to C:/Users/Alfa/Program Skripsi\geaNlp_weight_model2.h5
# Epoch 11/350
# 30/30 - 2s - loss: 0.8624 - accuracy: 0.6519 - val_loss: 0.8528 - val_accuracy: 0.6610
#
# Epoch 00011: val_accuracy improved from 0.64247 to 0.66096, saving model to C:/Users/Alfa/Program Skripsi\geaNlp_weight_model2.h5
# Epoch 12/350
# 30/30 - 2s - loss: 0.8044 - accuracy: 0.6761 - val_loss: 0.7981 - val_accuracy: 0.6745
#
# Epoch 00012: val_accuracy improved from 0.66096 to 0.67448, saving model to C:/Users/Alfa/Program Skripsi\geaNlp_weight_model2.h5
# Epoch 13/350
# 30/30 - 2s - loss: 0.7481 - accuracy: 0.6982 - val_loss: 0.7732 - val_accuracy: 0.6803
#
# Epoch 00013: val_accuracy improved from 0.67448 to 0.68034, saving model to C:/Users/Alfa/Program Skripsi\geaNlp_weight_model2.h5
# Epoch 14/350
# 30/30 - 2s - loss: 0.7037 - accuracy: 0.7185 - val_loss: 0.7280 - val_accuracy: 0.7137
#
# Epoch 00014: val_accuracy improved from 0.68034 to 0.71371, saving model to C:/Users/Alfa/Program Skripsi\geaNlp_weight_model2.h5
# Epoch 15/350
# 30/30 - 2s - loss: 0.6717 - accuracy: 0.7310 - val_loss: 0.6902 - val_accuracy: 0.7322
#
# Epoch 00015: val_accuracy improved from 0.71371 to 0.73219, saving model to C:/Users/Alfa/Program Skripsi\geaNlp_weight_model2.h5
# Epoch 16/350
# 30/30 - 2s - loss: 0.6339 - accuracy: 0.7493 - val_loss: 0.6610 - val_accuracy: 0.7466
#
# Epoch 00016: val_accuracy improved from 0.73219 to 0.74662, saving model to C:/Users/Alfa/Program Skripsi\geaNlp_weight_model2.h5
# Epoch 17/350
# 30/30 - 2s - loss: 0.5979 - accuracy: 0.7612 - val_loss: 0.6868 - val_accuracy: 0.7029
#
# Epoch 00017: val_accuracy did not improve from 0.74662
# Epoch 18/350
# 30/30 - 2s - loss: 0.5734 - accuracy: 0.7766 - val_loss: 0.6089 - val_accuracy: 0.7669
#
# Epoch 00018: val_accuracy improved from 0.74662 to 0.76691, saving model to C:/Users/Alfa/Program Skripsi\geaNlp_weight_model2.h5
# Epoch 19/350
# 30/30 - 2s - loss: 0.5473 - accuracy: 0.7870 - val_loss: 0.5946 - val_accuracy: 0.7759
#
# Epoch 00019: val_accuracy improved from 0.76691 to 0.77592, saving model to C:/Users/Alfa/Program Skripsi\geaNlp_weight_model2.h5
# Epoch 20/350
# 30/30 - 2s - loss: 0.5135 - accuracy: 0.8048 - val_loss: 0.5713 - val_accuracy: 0.7867
#
# Epoch 00020: val_accuracy improved from 0.77592 to 0.78674, saving model to C:/Users/Alfa/Program Skripsi\geaNlp_weight_model2.h5
# Epoch 21/350
# 30/30 - 2s - loss: 0.5004 - accuracy: 0.8045 - val_loss: 0.6014 - val_accuracy: 0.7723
#
# Epoch 00021: val_accuracy did not improve from 0.78674
# Epoch 22/350
# 30/30 - 2s - loss: 0.4837 - accuracy: 0.8136 - val_loss: 0.5549 - val_accuracy: 0.7872
#
# Epoch 00022: val_accuracy improved from 0.78674 to 0.78720, saving model to C:/Users/Alfa/Program Skripsi\geaNlp_weight_model2.h5
# Epoch 23/350
# 30/30 - 2s - loss: 0.4598 - accuracy: 0.8283 - val_loss: 0.5459 - val_accuracy: 0.7935
#
# Epoch 00023: val_accuracy improved from 0.78720 to 0.79351, saving model to C:/Users/Alfa/Program Skripsi\geaNlp_weight_model2.h5
# Epoch 24/350
# 30/30 - 2s - loss: 0.4423 - accuracy: 0.8338 - val_loss: 0.5259 - val_accuracy: 0.8079
#
# Epoch 00024: val_accuracy improved from 0.79351 to 0.80794, saving model to C:/Users/Alfa/Program Skripsi\geaNlp_weight_model2.h5
# Epoch 25/350
# 30/30 - 2s - loss: 0.4401 - accuracy: 0.8306 - val_loss: 0.5775 - val_accuracy: 0.7863
#
# Epoch 00025: val_accuracy did not improve from 0.80794
# Epoch 26/350
# 30/30 - 2s - loss: 0.4119 - accuracy: 0.8489 - val_loss: 0.5503 - val_accuracy: 0.8003
#
# Epoch 00026: val_accuracy did not improve from 0.80794
# Epoch 27/350
# 30/30 - 2s - loss: 0.4046 - accuracy: 0.8525 - val_loss: 0.6217 - val_accuracy: 0.7710
#
# Epoch 00027: val_accuracy did not improve from 0.80794
# Epoch 28/350
# 30/30 - 2s - loss: 0.3821 - accuracy: 0.8640 - val_loss: 0.5441 - val_accuracy: 0.8061
#
# Epoch 00028: val_accuracy did not improve from 0.80794
# Epoch 29/350
# 30/30 - 2s - loss: 0.3877 - accuracy: 0.8559 - val_loss: 0.5316 - val_accuracy: 0.8097
#
# Epoch 00029: val_accuracy improved from 0.80794 to 0.80974, saving model to C:/Users/Alfa/Program Skripsi\geaNlp_weight_model2.h5
# Epoch 30/350
# 30/30 - 2s - loss: 0.3631 - accuracy: 0.8697 - val_loss: 0.6865 - val_accuracy: 0.7493
#
# Epoch 00030: val_accuracy did not improve from 0.80974
# Epoch 31/350
# 30/30 - 2s - loss: 0.3700 - accuracy: 0.8662 - val_loss: 0.5294 - val_accuracy: 0.8147
#
# Epoch 00031: val_accuracy improved from 0.80974 to 0.81470, saving model to C:/Users/Alfa/Program Skripsi\geaNlp_weight_model2.h5
# Epoch 32/350
# 30/30 - 2s - loss: 0.3440 - accuracy: 0.8801 - val_loss: 0.5013 - val_accuracy: 0.8318
#
# Epoch 00032: val_accuracy improved from 0.81470 to 0.83183, saving model to C:/Users/Alfa/Program Skripsi\geaNlp_weight_model2.h5
# Epoch 33/350
# 30/30 - 2s - loss: 0.3410 - accuracy: 0.8790 - val_loss: 0.5509 - val_accuracy: 0.8161
#
# Epoch 00033: val_accuracy did not improve from 0.83183
# Epoch 34/350
# 30/30 - 2s - loss: 0.3388 - accuracy: 0.8820 - val_loss: 0.5312 - val_accuracy: 0.8133
#
# Epoch 00034: val_accuracy did not improve from 0.83183
# Epoch 35/350
# 30/30 - 2s - loss: 0.3273 - accuracy: 0.8859 - val_loss: 0.4957 - val_accuracy: 0.8363
#
# Epoch 00035: val_accuracy improved from 0.83183 to 0.83634, saving model to C:/Users/Alfa/Program Skripsi\geaNlp_weight_model2.h5
# Epoch 36/350
# 30/30 - 2s - loss: 0.3199 - accuracy: 0.8908 - val_loss: 0.6052 - val_accuracy: 0.7755
#
# Epoch 00036: val_accuracy did not improve from 0.83634
# Epoch 37/350
# 30/30 - 2s - loss: 0.3175 - accuracy: 0.8896 - val_loss: 0.5307 - val_accuracy: 0.8188
#
# Epoch 00037: val_accuracy did not improve from 0.83634
# Epoch 38/350
# 30/30 - 2s - loss: 0.2959 - accuracy: 0.9031 - val_loss: 0.6205 - val_accuracy: 0.7741
#
# Epoch 00038: val_accuracy did not improve from 0.83634
# Epoch 39/350
# 30/30 - 2s - loss: 0.3054 - accuracy: 0.8928 - val_loss: 0.5074 - val_accuracy: 0.8318
#
# Epoch 00039: val_accuracy did not improve from 0.83634
# Epoch 40/350
# 30/30 - 2s - loss: 0.2963 - accuracy: 0.8985 - val_loss: 0.6052 - val_accuracy: 0.7840
#
# Epoch 00040: val_accuracy did not improve from 0.83634
# Epoch 41/350
# 30/30 - 2s - loss: 0.2904 - accuracy: 0.9009 - val_loss: 0.5081 - val_accuracy: 0.8359
#
# Epoch 00041: val_accuracy did not improve from 0.83634
# Epoch 42/350
# 30/30 - 2s - loss: 0.2782 - accuracy: 0.9086 - val_loss: 0.5053 - val_accuracy: 0.8377
#
# Epoch 00042: val_accuracy improved from 0.83634 to 0.83769, saving model to C:/Users/Alfa/Program Skripsi\geaNlp_weight_model2.h5
# Epoch 43/350
# 30/30 - 2s - loss: 0.2784 - accuracy: 0.9075 - val_loss: 0.6241 - val_accuracy: 0.7967
#
# Epoch 00043: val_accuracy did not improve from 0.83769
# Epoch 44/350
# 30/30 - 2s - loss: 0.2624 - accuracy: 0.9154 - val_loss: 0.6512 - val_accuracy: 0.7917
#
# Epoch 00044: val_accuracy did not improve from 0.83769
# Epoch 45/350
# 30/30 - 2s - loss: 0.2850 - accuracy: 0.9019 - val_loss: 0.5369 - val_accuracy: 0.8408
#
# Epoch 00045: val_accuracy improved from 0.83769 to 0.84085, saving model to C:/Users/Alfa/Program Skripsi\geaNlp_weight_model2.h5
# Epoch 46/350
# 30/30 - 2s - loss: 0.2538 - accuracy: 0.9207 - val_loss: 0.5566 - val_accuracy: 0.8323
#
# Epoch 00046: val_accuracy did not improve from 0.84085
# Epoch 47/350
# 30/30 - 2s - loss: 0.2520 - accuracy: 0.9211 - val_loss: 0.5409 - val_accuracy: 0.8436
#
# Epoch 00047: val_accuracy improved from 0.84085 to 0.84355, saving model to C:/Users/Alfa/Program Skripsi\geaNlp_weight_model2.h5
# Epoch 48/350
# 30/30 - 2s - loss: 0.2583 - accuracy: 0.9150 - val_loss: 0.6107 - val_accuracy: 0.8156
#
# Epoch 00048: val_accuracy did not improve from 0.84355
# Epoch 49/350
# 30/30 - 2s - loss: 0.2578 - accuracy: 0.9137 - val_loss: 0.6490 - val_accuracy: 0.8012
#
# Epoch 00049: val_accuracy did not improve from 0.84355
# Epoch 50/350
# 30/30 - 2s - loss: 0.2360 - accuracy: 0.9254 - val_loss: 0.5445 - val_accuracy: 0.8445
#
# Epoch 00050: val_accuracy improved from 0.84355 to 0.84445, saving model to C:/Users/Alfa/Program Skripsi\geaNlp_weight_model2.h5
# Epoch 51/350
# 30/30 - 2s - loss: 0.2477 - accuracy: 0.9193 - val_loss: 0.5242 - val_accuracy: 0.8553
#
# Akurasi validasi telah mencapai > 85%!
#
# Epoch 00051: val_accuracy improved from 0.84445 to 0.85528, saving model to C:/Users/Alfa/Program Skripsi\geaNlp_weight_model2.h5

# %%
# Save model yang telah dijalankan
#model.save("lstmModel1.h5")

# %%
# Menampilkan plot loss dari model
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])
plt.show()

# %%
# Menampilkan plot akurasi dari model
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'validation'])
plt.show()

# %% [markdown]
# # Evaluasi Model

# %%
loss, acc = model.evaluate(padded_test, y_test, verbose=1)
                            #batch_size=batch_size)
print("loss:", loss)
print("Validation accuracy:", acc)
# Out:
# 70/70 [==============================] - 0s 6ms/step - loss: 0.5242 - accuracy: 0.8553
# loss: 0.5242246985435486
# Validation accuracy: 0.85527503490448

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

def model_evaluate(): 
    # predict class with test set
    y_pred_test =  model.predict_classes(padded_test, verbose=0)
    print('Accuracy:\t{:0.1f}%'.format(accuracy_score(np.argmax(y_test,axis=1),y_pred_test)*100))
    
    #classification report
    print('\n')
    print(classification_report(np.argmax(y_test,axis=1), y_pred_test))

    #confusion matrix
    confmat = confusion_matrix(np.argmax(y_test,axis=1), y_pred_test)

    fig, ax = plt.subplots(figsize=(4, 4))
    ax.matshow(confmat, cmap=plt.cm.Blues, alpha=0.3)
    for i in range(confmat.shape[0]):
        for j in range(confmat.shape[1]):
            ax.text(x=j, y=i, s=confmat[i, j], va='center', ha='center')
    plt.xlabel('Predicted label')
    plt.ylabel('True label')
    plt.tight_layout()

# %%
model_evaluate()
# Out:
# C:\Users\Alfa\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\keras\engine\sequential.py:455: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# Accuracy:	85.5%
#
#
#               precision    recall  f1-score   support
#
#            0       0.90      0.93      0.92      1068
#            1       0.71      0.68      0.70       498
#            2       0.88      0.86      0.87       652
#
#     accuracy                           0.86      2218
#    macro avg       0.83      0.83      0.83      2218
# weighted avg       0.85      0.86      0.85      2218

# %%
twt = ['covid menambah jumlah kematian dan ekonomi menurun']
print(twt)
#vectorizing the tweet by the pre-fitted tokenizer instance
twt = tokenizer.texts_to_sequences(twt)
#padding the tweet to have exactly the same shape as `embedding_2` input
twt = pad_sequences(twt, maxlen=29, dtype='int32', value=0)
#print(twt)
sentiment = model.predict(twt)[0]
if(np.argmax(sentiment) == 0):
    print('Sentimen: Negatif')
elif (np.argmax(sentiment) == 1):
    print('Sentimen: Netral')
else :
    print('Sentimen: Positif')
print(sentiment)
# Out:
# ['covid menambah jumlah kematian dan ekonomi menurun']
# Sentimen: Negatif
# [9.9767655e-01 2.3222470e-03 1.1544797e-06]

# %%
twt = ['1000 orang telah sehat dan sembuh']
print(twt)
#vectorizing the tweet by the pre-fitted tokenizer instance
twt = tokenizer.texts_to_sequences(twt)
#padding the tweet to have exactly the same shape as `embedding_2` input
twt = pad_sequences(twt, maxlen=29, dtype='int32', value=0)
#print(twt)
sentiment = model.predict(twt)[0]
print(sentiment)
if(np.argmax(sentiment) == 0):
    print('Sentimen: Negatif')
elif (np.argmax(sentiment) == 1):
    print('Sentimen: Netral')
else :
    print('Sentimen: Positif')
# Out:
# ['1000 orang telah sehat dan sembuh']
# [9.1689383e-04 5.6117114e-02 9.4296604e-01]
# Sentimen: Positif

# %% [markdown]
# # Cross Validation

# %%
# MLP for Pima Indians Dataset with 10-fold cross validation
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import StratifiedKFold
import numpy
# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)
# load pima indians dataset
dataset = numpy.loadtxt("pima-indians-diabetes.csv", delimiter=",")
# split into input (X) and output (Y) variables
X = dataset[:,0:8]
Y = dataset[:,8]
# define 10-fold cross validation test harness
kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=seed)
cvscores = []
for train, test in kfold.split(X, Y):
  # create model
    model = Sequential()
    model.add(Dense(12, input_dim=8, activation='relu'))
    model.add(Dense(8, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    # Compile model
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    # Fit the model
    model.fit(X[train], Y[train], epochs=150, batch_size=10, verbose=0)
    # evaluate the model
    scores = model.evaluate(X[test], Y[test], verbose=0)
    print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
    cvscores.append(scores[1] * 100)
print("%.2f%% (+/- %.2f%%)" % (numpy.mean(cvscores), numpy.std(cvscores)))


kfold=KFold(10,True,7)
cvscores = []

x=np.array(x)
y=np.array(y)

for train, test in kfold.split(x,y):

    X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)
    X_train = np.reshape(X_train, (X_train.shape[0], 1, 8))
    X_test = np.reshape(X_test, (X_test.shape[0], 1, 8))

    output_size=1 
    neurons=100 
    activ_func="tanh"
    dropout=0.25
    loss="mean_squared_error" 
    optimizer="sgd"
    model = Sequential()
    model.add(LSTM(neurons,return_sequences=True,input_shape=(1,8)))
    model.add(LSTM(90))
 
    model.add(Dropout(dropout))
    
    model.add(Dense(units=output_size))
    model.add(Activation(activ_func))
    model.compile(loss=loss, optimizer='adam',metrics =["mae"])
    model.fit(X_train, y_train, epochs=10, batch_size=10, verbose=0,shuffle=False)
    scores = model.evaluate(X_test, y_test, verbose=0)
    print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
    cvscores.append(scores[1] * 100)
print("%.2f%% (+/- %.2f%%)" % (np.mean(cvscores), np.std(cvscores)))

# %%
# Membagi data menjadi 90% data train dan 10% data test
from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split,KFold,cross_val_score
from sklearn.model_selection import StratifiedKFold

x=tweet_sentimen
y=label
#kfold=StratifiedKFold(n_splits=10, shuffle=True, random_state=7)
kfold=KFold(n_splits=5, shuffle=True, random_state=42)
cvscores = []

# %%
#x_test
for train, test in kfold.split(tweet_sentimen,label):
    x_train, x_test, y_train, y_test = train_test_split(tweet_sentimen, label, test_size=0.1)

    tokenizer2 = Tokenizer(num_words=6500, oov_token='-')
    tokenizer2.fit_on_texts(x_train) 
    tokenizer2.fit_on_texts(x_test)

    # Memasukkan data train dan test ke dalam sequence
    sekuens_latih2 = tokenizer2.texts_to_sequences(x_train)
    sekuens_test2 = tokenizer2.texts_to_sequences(x_test)

    # Menggunakan padding agar sequence menjadi sama panjang
    padded_latih2 = pad_sequences(sekuens_latih2) 
    padded_test2 = pad_sequences(sekuens_test2)
       
    # Membuat model Sequential dengan Bidirectional LSTM
    model = tf.keras.Sequential([
    tf.keras.layers.Embedding(6500, 32), # 6500 input & 32 layer embedding
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64,  return_sequences=True)), # 64 layer LSTM
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)), # 32 layer LSTM
    tf.keras.layers.Dense(128, activation='relu'), # Menambah layer dan menggunakan relu sebagai fungsi aktivasi
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(512, kernel_regularizer=regularizers.l2(0.001), activation='relu'), #kernel_regularizer=regularizers.l2(0.0001),
    tf.keras.layers.Dropout(0.5), # Menggunakan dropout agar model tidak overfitting
    tf.keras.layers.Dense(3, activation='softmax') # Outputnya adalah 3 dan karena kategorikal menggunakan aktivasi softmax
    ])

    #model.summary() # Melihat shape dan parameter model
    model.compile(loss='categorical_crossentropy', optimizer=RMSprop(learning_rate=0.0001),metrics=['accuracy']) # Menggunakan optimizer RMSprop dengan learning rate 0.0001
    history2 = model.fit(padded_latih2, y_train, validation_data=(padded_test2, y_test), epochs=50,
                    steps_per_epoch= 30, callbacks=[checkpoint], verbose=2)
    
    evalcross = model.evaluate(padded_test2, y_test, verbose=0)
    print("%s: %.2f%%" % (model.metrics_names[1], evalcross[1]*100))
    cvscores.append(evalcross[1] * 100)
    
print("%.2f%% (+/- %.2f%%)" % (np.mean(cvscores), np.std(cvscores)))
# Out:
# Epoch 1/50
# 30/30 - 9s - loss: 1.2739 - accuracy: 0.4717 - val_loss: 1.2485 - val_accuracy: 0.4689
#
# Epoch 00001: val_accuracy did not improve from 0.85708
# Epoch 2/50
# 30/30 - 2s - loss: 1.2249 - accuracy: 0.4782 - val_loss: 1.2195 - val_accuracy: 0.4689
#
# Epoch 00002: val_accuracy did not improve from 0.85708
# Epoch 3/50
# 30/30 - 2s - loss: 1.1925 - accuracy: 0.4783 - val_loss: 1.1842 - val_accuracy: 0.4689
#
# Epoch 00003: val_accuracy did not improve from 0.85708
# Epoch 4/50
# 30/30 - 2s - loss: 1.1596 - accuracy: 0.4813 - val_loss: 1.1517 - val_accuracy: 0.4806
#
# Epoch 00004: val_accuracy did not improve from 0.85708
# Epoch 5/50
# 30/30 - 2s - loss: 1.1277 - accuracy: 0.5053 - val_loss: 1.1165 - val_accuracy: 0.5131
#
# Epoch 00005: val_accuracy did not improve from 0.85708
# Epoch 6/50
# 30/30 - 2s - loss: 1.0835 - accuracy: 0.5363 - val_loss: 1.0704 - val_accuracy: 0.5406
#
# Epoch 00006: val_accuracy did not improve from 0.85708
# Epoch 7/50
# 30/30 - 2s - loss: 1.0171 - accuracy: 0.5852 - val_loss: 1.0179 - val_accuracy: 0.5726
#
# Epoch 00007: val_accuracy did not improve from 0.85708
# Epoch 8/50
# 30/30 - 2s - loss: 0.9504 - accuracy: 0.6267 - val_loss: 0.9507 - val_accuracy: 0.6136
#
# Epoch 00008: val_accuracy did not improve from 0.85708
# Epoch 9/50
# 30/30 - 2s - loss: 0.8799 - accuracy: 0.6605 - val_loss: 0.9557 - val_accuracy: 0.5870
#
# Epoch 00009: val_accuracy did not improve from 0.85708
# Epoch 10/50
# 30/30 - 2s - loss: 0.8253 - accuracy: 0.6778 - val_loss: 0.8860 - val_accuracy: 0.6276
#
# Epoch 00010: val_accuracy did not improve from 0.85708
# Epoch 11/50
# 30/30 - 2s - loss: 0.7715 - accuracy: 0.6996 - val_loss: 0.8547 - val_accuracy: 0.6470
#
# Epoch 00011: val_accuracy did not improve from 0.85708
# Epoch 12/50
# 30/30 - 2s - loss: 0.7230 - accuracy: 0.7166 - val_loss: 0.9056 - val_accuracy: 0.6109
#
# Epoch 00012: val_accuracy did not improve from 0.85708
# Epoch 13/50
# 30/30 - 2s - loss: 0.6843 - accuracy: 0.7331 - val_loss: 0.9019 - val_accuracy: 0.6100
#
# Epoch 00013: val_accuracy did not improve from 0.85708
# Epoch 14/50
# 30/30 - 2s - loss: 0.6437 - accuracy: 0.7530 - val_loss: 0.7015 - val_accuracy: 0.7362
#
# Epoch 00014: val_accuracy did not improve from 0.85708
# Epoch 15/50
# 30/30 - 2s - loss: 0.6148 - accuracy: 0.7613 - val_loss: 0.6791 - val_accuracy: 0.7502
#
# Epoch 00015: val_accuracy did not improve from 0.85708
# Epoch 16/50
# 30/30 - 2s - loss: 0.5794 - accuracy: 0.7788 - val_loss: 0.6738 - val_accuracy: 0.7453
#
# Epoch 00016: val_accuracy did not improve from 0.85708
# Epoch 17/50
# 30/30 - 2s - loss: 0.5563 - accuracy: 0.7863 - val_loss: 0.8530 - val_accuracy: 0.6398
#
# Epoch 00017: val_accuracy did not improve from 0.85708
# Epoch 18/50
# 30/30 - 2s - loss: 0.5302 - accuracy: 0.7963 - val_loss: 0.6286 - val_accuracy: 0.7647
#
# Epoch 00018: val_accuracy did not improve from 0.85708
# Epoch 19/50
# 30/30 - 2s - loss: 0.5046 - accuracy: 0.8090 - val_loss: 0.6155 - val_accuracy: 0.7696
#
# Epoch 00019: val_accuracy did not improve from 0.85708
# Epoch 20/50
# 30/30 - 2s - loss: 0.4894 - accuracy: 0.8174 - val_loss: 0.6053 - val_accuracy: 0.7773
#
# Epoch 00020: val_accuracy did not improve from 0.85708
# Epoch 21/50
# 30/30 - 2s - loss: 0.4581 - accuracy: 0.8358 - val_loss: 0.5975 - val_accuracy: 0.7840
#
# Epoch 00021: val_accuracy did not improve from 0.85708
# Epoch 22/50
# 30/30 - 2s - loss: 0.4597 - accuracy: 0.8271 - val_loss: 0.6110 - val_accuracy: 0.7786
#
# Epoch 00022: val_accuracy did not improve from 0.85708
# Epoch 23/50
# 30/30 - 2s - loss: 0.4302 - accuracy: 0.8432 - val_loss: 0.5858 - val_accuracy: 0.7967
#
# Epoch 00023: val_accuracy did not improve from 0.85708
# Epoch 24/50
# 30/30 - 2s - loss: 0.4264 - accuracy: 0.8471 - val_loss: 0.6191 - val_accuracy: 0.7773
#
# Epoch 00024: val_accuracy did not improve from 0.85708
# Epoch 25/50
# 30/30 - 2s - loss: 0.4087 - accuracy: 0.8524 - val_loss: 0.7749 - val_accuracy: 0.7051
#
# Epoch 00025: val_accuracy did not improve from 0.85708
# Epoch 26/50
# 30/30 - 2s - loss: 0.4063 - accuracy: 0.8487 - val_loss: 0.7624 - val_accuracy: 0.7160
#
# Epoch 00026: val_accuracy did not improve from 0.85708
# Epoch 27/50
# 30/30 - 2s - loss: 0.3799 - accuracy: 0.8659 - val_loss: 0.6248 - val_accuracy: 0.7687
#
# Epoch 00027: val_accuracy did not improve from 0.85708
# Epoch 28/50
# 30/30 - 2s - loss: 0.3858 - accuracy: 0.8594 - val_loss: 0.5772 - val_accuracy: 0.8088
#
# Epoch 00028: val_accuracy did not improve from 0.85708
# Epoch 29/50
# 30/30 - 2s - loss: 0.3671 - accuracy: 0.8649 - val_loss: 0.5712 - val_accuracy: 0.8075
#
# Epoch 00029: val_accuracy did not improve from 0.85708
# Epoch 30/50
# 30/30 - 2s - loss: 0.3674 - accuracy: 0.8672 - val_loss: 0.5912 - val_accuracy: 0.7913
#
# Epoch 00030: val_accuracy did not improve from 0.85708
# Epoch 31/50
# 30/30 - 2s - loss: 0.3596 - accuracy: 0.8670 - val_loss: 0.5639 - val_accuracy: 0.8102
#
# Epoch 00031: val_accuracy did not improve from 0.85708
# Epoch 32/50
# 30/30 - 2s - loss: 0.3492 - accuracy: 0.8766 - val_loss: 0.5607 - val_accuracy: 0.8201
#
# Epoch 00032: val_accuracy did not improve from 0.85708
# Epoch 33/50
# 30/30 - 2s - loss: 0.3491 - accuracy: 0.8741 - val_loss: 0.5624 - val_accuracy: 0.8174
#
# Epoch 00033: val_accuracy did not improve from 0.85708
# Epoch 34/50
# 30/30 - 2s - loss: 0.3288 - accuracy: 0.8869 - val_loss: 0.5925 - val_accuracy: 0.7894
#
# Epoch 00034: val_accuracy did not improve from 0.85708
# Epoch 35/50
# 30/30 - 2s - loss: 0.3269 - accuracy: 0.8848 - val_loss: 0.5711 - val_accuracy: 0.8197
#
# Epoch 00035: val_accuracy did not improve from 0.85708
# Epoch 36/50
# 30/30 - 2s - loss: 0.3159 - accuracy: 0.8908 - val_loss: 0.5745 - val_accuracy: 0.8228
#
# Epoch 00036: val_accuracy did not improve from 0.85708
# Epoch 37/50
# 30/30 - 2s - loss: 0.3231 - accuracy: 0.8869 - val_loss: 0.9835 - val_accuracy: 0.6767
#
# Epoch 00037: val_accuracy did not improve from 0.85708
# Epoch 38/50
# 30/30 - 2s - loss: 0.3135 - accuracy: 0.8907 - val_loss: 0.7314 - val_accuracy: 0.7484
#
# Epoch 00038: val_accuracy did not improve from 0.85708
# Epoch 39/50
# 30/30 - 2s - loss: 0.3059 - accuracy: 0.8938 - val_loss: 0.8655 - val_accuracy: 0.7146
#
# Epoch 00039: val_accuracy did not improve from 0.85708
# Epoch 40/50
# 30/30 - 2s - loss: 0.2993 - accuracy: 0.8958 - val_loss: 0.7767 - val_accuracy: 0.7399
#
# Epoch 00040: val_accuracy did not improve from 0.85708
# Epoch 41/50
# 30/30 - 2s - loss: 0.2884 - accuracy: 0.9011 - val_loss: 0.8779 - val_accuracy: 0.7191
#
# Epoch 00041: val_accuracy did not improve from 0.85708
# Epoch 42/50
# 30/30 - 2s - loss: 0.2840 - accuracy: 0.9050 - val_loss: 0.8142 - val_accuracy: 0.7385
#
# Epoch 00042: val_accuracy did not improve from 0.85708
# Epoch 43/50
# 30/30 - 2s - loss: 0.2829 - accuracy: 0.9055 - val_loss: 0.9180 - val_accuracy: 0.7119
#
# Epoch 00043: val_accuracy did not improve from 0.85708
# Epoch 44/50
# 30/30 - 2s - loss: 0.2819 - accuracy: 0.9043 - val_loss: 0.6756 - val_accuracy: 0.7917
#
# Epoch 00044: val_accuracy did not improve from 0.85708
# Epoch 45/50
# 30/30 - 2s - loss: 0.2836 - accuracy: 0.9044 - val_loss: 0.5892 - val_accuracy: 0.8278
#
# Epoch 00045: val_accuracy did not improve from 0.85708
# Epoch 46/50
# 30/30 - 2s - loss: 0.2664 - accuracy: 0.9121 - val_loss: 0.6319 - val_accuracy: 0.7917
#
# Epoch 00046: val_accuracy did not improve from 0.85708
# Epoch 47/50
# 30/30 - 2s - loss: 0.2780 - accuracy: 0.9034 - val_loss: 0.7843 - val_accuracy: 0.7507
#
# Epoch 00047: val_accuracy did not improve from 0.85708
# Epoch 48/50
# 30/30 - 2s - loss: 0.2642 - accuracy: 0.9118 - val_loss: 0.7444 - val_accuracy: 0.7638
#
# Epoch 00048: val_accuracy did not improve from 0.85708
# Epoch 49/50
# 30/30 - 2s - loss: 0.2540 - accuracy: 0.9171 - val_loss: 0.9714 - val_accuracy: 0.7087
#
# Epoch 00049: val_accuracy did not improve from 0.85708
# Epoch 50/50
# 30/30 - 2s - loss: 0.2463 - accuracy: 0.9229 - val_loss: 0.6752 - val_accuracy: 0.7985
#
# Epoch 00050: val_accuracy did not improve from 0.85708
# accuracy: 79.85%
# Epoch 1/50
# 30/30 - 9s - loss: 1.2734 - accuracy: 0.4733 - val_loss: 1.2448 - val_accuracy: 0.4711
#
# Epoch 00001: val_accuracy did not improve from 0.85708
# Epoch 2/50
# 30/30 - 2s - loss: 1.2262 - accuracy: 0.4780 - val_loss: 1.2158 - val_accuracy: 0.4711
#
# Epoch 00002: val_accuracy did not improve from 0.85708
# Epoch 3/50
# 30/30 - 2s - loss: 1.1984 - accuracy: 0.4780 - val_loss: 1.1833 - val_accuracy: 0.4711
#
# Epoch 00003: val_accuracy did not improve from 0.85708
# Epoch 4/50
# 30/30 - 2s - loss: 1.1611 - accuracy: 0.4779 - val_loss: 1.1491 - val_accuracy: 0.4711
#
# Epoch 00004: val_accuracy did not improve from 0.85708
# Epoch 5/50
# 30/30 - 2s - loss: 1.1286 - accuracy: 0.5008 - val_loss: 1.1189 - val_accuracy: 0.5131
#
# Epoch 00005: val_accuracy did not improve from 0.85708
# Epoch 6/50
# 30/30 - 2s - loss: 1.0919 - accuracy: 0.5370 - val_loss: 1.0782 - val_accuracy: 0.5586
#
# Epoch 00006: val_accuracy did not improve from 0.85708
# Epoch 7/50
# 30/30 - 2s - loss: 1.0357 - accuracy: 0.5766 - val_loss: 1.0143 - val_accuracy: 0.6073
#
# Epoch 00007: val_accuracy did not improve from 0.85708
# Epoch 8/50
# 30/30 - 2s - loss: 0.9581 - accuracy: 0.6255 - val_loss: 0.9380 - val_accuracy: 0.6344
#
# Epoch 00008: val_accuracy did not improve from 0.85708
# Epoch 9/50
# 30/30 - 2s - loss: 0.8867 - accuracy: 0.6566 - val_loss: 0.8767 - val_accuracy: 0.6587
#
# Epoch 00009: val_accuracy did not improve from 0.85708
# Epoch 10/50
# 30/30 - 2s - loss: 0.8196 - accuracy: 0.6792 - val_loss: 0.8098 - val_accuracy: 0.6754
#
# Epoch 00010: val_accuracy did not improve from 0.85708
# Epoch 11/50
# 30/30 - 2s - loss: 0.7638 - accuracy: 0.7017 - val_loss: 0.7757 - val_accuracy: 0.6957
#
# Epoch 00011: val_accuracy did not improve from 0.85708
# Epoch 12/50
# 30/30 - 2s - loss: 0.7197 - accuracy: 0.7151 - val_loss: 0.7315 - val_accuracy: 0.7169
#
# Epoch 00012: val_accuracy did not improve from 0.85708
# Epoch 13/50
# 30/30 - 2s - loss: 0.6727 - accuracy: 0.7404 - val_loss: 0.7869 - val_accuracy: 0.6551
#
# Epoch 00013: val_accuracy did not improve from 0.85708
# Epoch 14/50
# 30/30 - 2s - loss: 0.6436 - accuracy: 0.7476 - val_loss: 0.7023 - val_accuracy: 0.7182
#
# Epoch 00014: val_accuracy did not improve from 0.85708
# Epoch 15/50
# 30/30 - 2s - loss: 0.6042 - accuracy: 0.7676 - val_loss: 0.6735 - val_accuracy: 0.7245
#
# Epoch 00015: val_accuracy did not improve from 0.85708
# Epoch 16/50
# 30/30 - 2s - loss: 0.5758 - accuracy: 0.7767 - val_loss: 0.6737 - val_accuracy: 0.7205
#
# Epoch 00016: val_accuracy did not improve from 0.85708
# Epoch 17/50
# 30/30 - 2s - loss: 0.5559 - accuracy: 0.7830 - val_loss: 0.6638 - val_accuracy: 0.7200
#
# Epoch 00017: val_accuracy did not improve from 0.85708
# Epoch 18/50
# 30/30 - 2s - loss: 0.5263 - accuracy: 0.7972 - val_loss: 0.7474 - val_accuracy: 0.6709
#
# Epoch 00018: val_accuracy did not improve from 0.85708
# Epoch 19/50
# 30/30 - 2s - loss: 0.5064 - accuracy: 0.8098 - val_loss: 0.6128 - val_accuracy: 0.7732
#
# Epoch 00019: val_accuracy did not improve from 0.85708
# Epoch 20/50
# 30/30 - 2s - loss: 0.4907 - accuracy: 0.8090 - val_loss: 0.5664 - val_accuracy: 0.7976
#
# Epoch 00020: val_accuracy did not improve from 0.85708
# Epoch 21/50
# 30/30 - 2s - loss: 0.4665 - accuracy: 0.8260 - val_loss: 0.5799 - val_accuracy: 0.7913
#
# Epoch 00021: val_accuracy did not improve from 0.85708
# Epoch 22/50
# 30/30 - 2s - loss: 0.4525 - accuracy: 0.8302 - val_loss: 0.5986 - val_accuracy: 0.7795
#
# Epoch 00022: val_accuracy did not improve from 0.85708
# Epoch 23/50
# 30/30 - 2s - loss: 0.4350 - accuracy: 0.8364 - val_loss: 0.5757 - val_accuracy: 0.7944
#
# Epoch 00023: val_accuracy did not improve from 0.85708
# Epoch 24/50
# 30/30 - 2s - loss: 0.4236 - accuracy: 0.8411 - val_loss: 0.5888 - val_accuracy: 0.7849
#
# Epoch 00024: val_accuracy did not improve from 0.85708
# Epoch 25/50
# 30/30 - 2s - loss: 0.4101 - accuracy: 0.8512 - val_loss: 0.5811 - val_accuracy: 0.7885
#
# Epoch 00025: val_accuracy did not improve from 0.85708
# Epoch 26/50
# 30/30 - 2s - loss: 0.3968 - accuracy: 0.8533 - val_loss: 0.5594 - val_accuracy: 0.8030
#
# Epoch 00026: val_accuracy did not improve from 0.85708
# Epoch 27/50
# 30/30 - 2s - loss: 0.3826 - accuracy: 0.8615 - val_loss: 0.6298 - val_accuracy: 0.7475
#
# Epoch 00027: val_accuracy did not improve from 0.85708
# Epoch 28/50
# 30/30 - 2s - loss: 0.3781 - accuracy: 0.8624 - val_loss: 0.5219 - val_accuracy: 0.8102
#
# Epoch 00028: val_accuracy did not improve from 0.85708
# Epoch 29/50
# 30/30 - 2s - loss: 0.3593 - accuracy: 0.8732 - val_loss: 0.5339 - val_accuracy: 0.8039
#
# Epoch 00029: val_accuracy did not improve from 0.85708
# Epoch 30/50
# 30/30 - 2s - loss: 0.3575 - accuracy: 0.8735 - val_loss: 0.6585 - val_accuracy: 0.7362
#
# Epoch 00030: val_accuracy did not improve from 0.85708
# Epoch 31/50
# 30/30 - 2s - loss: 0.3432 - accuracy: 0.8794 - val_loss: 0.5769 - val_accuracy: 0.7773
#
# Epoch 00031: val_accuracy did not improve from 0.85708
# Epoch 32/50
# 30/30 - 2s - loss: 0.3341 - accuracy: 0.8876 - val_loss: 0.5151 - val_accuracy: 0.8269
#
# Epoch 00032: val_accuracy did not improve from 0.85708
# Epoch 33/50
# 30/30 - 2s - loss: 0.3253 - accuracy: 0.8878 - val_loss: 0.6617 - val_accuracy: 0.7426
#
# Epoch 00033: val_accuracy did not improve from 0.85708
# Epoch 34/50
# 30/30 - 2s - loss: 0.3217 - accuracy: 0.8903 - val_loss: 0.5449 - val_accuracy: 0.7994
#
# Epoch 00034: val_accuracy did not improve from 0.85708
# Epoch 35/50
# 30/30 - 2s - loss: 0.2992 - accuracy: 0.8998 - val_loss: 0.6258 - val_accuracy: 0.7642
#
# Epoch 00035: val_accuracy did not improve from 0.85708
# Epoch 36/50
# 30/30 - 2s - loss: 0.3100 - accuracy: 0.8948 - val_loss: 0.5311 - val_accuracy: 0.8300
#
# Epoch 00036: val_accuracy did not improve from 0.85708
# Epoch 37/50
# 30/30 - 2s - loss: 0.3031 - accuracy: 0.8964 - val_loss: 0.6091 - val_accuracy: 0.8124
#
# Epoch 00037: val_accuracy did not improve from 0.85708
# Epoch 38/50
# 30/30 - 2s - loss: 0.2877 - accuracy: 0.9045 - val_loss: 0.5226 - val_accuracy: 0.8309
#
# Epoch 00038: val_accuracy did not improve from 0.85708
# Epoch 39/50
# 30/30 - 2s - loss: 0.2852 - accuracy: 0.9059 - val_loss: 0.5282 - val_accuracy: 0.8431
#
# Epoch 00039: val_accuracy did not improve from 0.85708
# Epoch 40/50
# 30/30 - 2s - loss: 0.2779 - accuracy: 0.9088 - val_loss: 0.6929 - val_accuracy: 0.7935
#
# Epoch 00040: val_accuracy did not improve from 0.85708
# Epoch 41/50
# 30/30 - 2s - loss: 0.2761 - accuracy: 0.9117 - val_loss: 0.6986 - val_accuracy: 0.7899
#
# Epoch 00041: val_accuracy did not improve from 0.85708
# Epoch 42/50
# 30/30 - 2s - loss: 0.2731 - accuracy: 0.9129 - val_loss: 0.5545 - val_accuracy: 0.8097
#
# Epoch 00042: val_accuracy did not improve from 0.85708
# Epoch 43/50
# 30/30 - 2s - loss: 0.2742 - accuracy: 0.9092 - val_loss: 0.6229 - val_accuracy: 0.7800
#
# Epoch 00043: val_accuracy did not improve from 0.85708
# Epoch 44/50
# 30/30 - 2s - loss: 0.2566 - accuracy: 0.9176 - val_loss: 0.5587 - val_accuracy: 0.8133
#
# Epoch 00044: val_accuracy did not improve from 0.85708
# Epoch 45/50
# 30/30 - 2s - loss: 0.2609 - accuracy: 0.9141 - val_loss: 0.6445 - val_accuracy: 0.8165
#
# Epoch 00045: val_accuracy did not improve from 0.85708
# Epoch 46/50
# 30/30 - 2s - loss: 0.2493 - accuracy: 0.9220 - val_loss: 0.6251 - val_accuracy: 0.8233
#
# Epoch 00046: val_accuracy did not improve from 0.85708
# Epoch 47/50
# 30/30 - 2s - loss: 0.2512 - accuracy: 0.9181 - val_loss: 0.5434 - val_accuracy: 0.8458
#
# Epoch 00047: val_accuracy did not improve from 0.85708
# Epoch 48/50
# 30/30 - 2s - loss: 0.2382 - accuracy: 0.9238 - val_loss: 0.5718 - val_accuracy: 0.8417
#
# Epoch 00048: val_accuracy did not improve from 0.85708
# Epoch 49/50
# 30/30 - 2s - loss: 0.2371 - accuracy: 0.9260 - val_loss: 0.5526 - val_accuracy: 0.8341
#
# Epoch 00049: val_accuracy did not improve from 0.85708
# Epoch 50/50
# 30/30 - 2s - loss: 0.2330 - accuracy: 0.9298 - val_loss: 0.5665 - val_accuracy: 0.8210
#
# Epoch 00050: val_accuracy did not improve from 0.85708
# accuracy: 82.10%
# Epoch 1/50
# 30/30 - 8s - loss: 1.2722 - accuracy: 0.4720 - val_loss: 1.2378 - val_accuracy: 0.4806
#
# Epoch 00001: val_accuracy did not improve from 0.85708
# Epoch 2/50
# 30/30 - 2s - loss: 1.2279 - accuracy: 0.4769 - val_loss: 1.2139 - val_accuracy: 0.4806
#
# Epoch 00002: val_accuracy did not improve from 0.85708
# Epoch 3/50
# 30/30 - 2s - loss: 1.2082 - accuracy: 0.4769 - val_loss: 1.1907 - val_accuracy: 0.4806
#
# Epoch 00003: val_accuracy did not improve from 0.85708
# Epoch 4/50
# 30/30 - 2s - loss: 1.1796 - accuracy: 0.4769 - val_loss: 1.1555 - val_accuracy: 0.4806
#
# Epoch 00004: val_accuracy did not improve from 0.85708
# Epoch 5/50
# 30/30 - 2s - loss: 1.1450 - accuracy: 0.4775 - val_loss: 1.1252 - val_accuracy: 0.4806
#
# Epoch 00005: val_accuracy did not improve from 0.85708
# Epoch 6/50
# 30/30 - 2s - loss: 1.1134 - accuracy: 0.5017 - val_loss: 1.0933 - val_accuracy: 0.5266
#
# Epoch 00006: val_accuracy did not improve from 0.85708
# Epoch 7/50
# 30/30 - 2s - loss: 1.0711 - accuracy: 0.5420 - val_loss: 1.0449 - val_accuracy: 0.5690
#
# Epoch 00007: val_accuracy did not improve from 0.85708
# Epoch 8/50
# 30/30 - 2s - loss: 1.0132 - accuracy: 0.5865 - val_loss: 0.9949 - val_accuracy: 0.6023
#
# Epoch 00008: val_accuracy did not improve from 0.85708
# Epoch 9/50
# 30/30 - 2s - loss: 0.9483 - accuracy: 0.6261 - val_loss: 0.9339 - val_accuracy: 0.6366
#
# Epoch 00009: val_accuracy did not improve from 0.85708
# Epoch 10/50
# 30/30 - 2s - loss: 0.8848 - accuracy: 0.6519 - val_loss: 0.8964 - val_accuracy: 0.6510
#
# Epoch 00010: val_accuracy did not improve from 0.85708
# Epoch 11/50
# 30/30 - 2s - loss: 0.8310 - accuracy: 0.6660 - val_loss: 0.8086 - val_accuracy: 0.6830
#
# Epoch 00011: val_accuracy did not improve from 0.85708
# Epoch 12/50
# 30/30 - 2s - loss: 0.7700 - accuracy: 0.6940 - val_loss: 0.7469 - val_accuracy: 0.7160
#
# Epoch 00012: val_accuracy did not improve from 0.85708
# Epoch 13/50
# 30/30 - 2s - loss: 0.7262 - accuracy: 0.7090 - val_loss: 0.7391 - val_accuracy: 0.7069
#
# Epoch 00013: val_accuracy did not improve from 0.85708
# Epoch 14/50
# 30/30 - 2s - loss: 0.6813 - accuracy: 0.7306 - val_loss: 0.6807 - val_accuracy: 0.7381
#
# Epoch 00014: val_accuracy did not improve from 0.85708
# Epoch 15/50
# 30/30 - 2s - loss: 0.6449 - accuracy: 0.7465 - val_loss: 0.6527 - val_accuracy: 0.7480
#
# Epoch 00015: val_accuracy did not improve from 0.85708
# Epoch 16/50
# 30/30 - 2s - loss: 0.6151 - accuracy: 0.7531 - val_loss: 0.6770 - val_accuracy: 0.7304
#
# Epoch 00016: val_accuracy did not improve from 0.85708
# Epoch 17/50
# 30/30 - 2s - loss: 0.5771 - accuracy: 0.7762 - val_loss: 0.6201 - val_accuracy: 0.7565
#
# Epoch 00017: val_accuracy did not improve from 0.85708
# Epoch 18/50
# 30/30 - 2s - loss: 0.5548 - accuracy: 0.7817 - val_loss: 0.6345 - val_accuracy: 0.7408
#
# Epoch 00018: val_accuracy did not improve from 0.85708
# Epoch 19/50
# 30/30 - 2s - loss: 0.5294 - accuracy: 0.7938 - val_loss: 0.5737 - val_accuracy: 0.7908
#
# Epoch 00019: val_accuracy did not improve from 0.85708
# Epoch 20/50
# 30/30 - 2s - loss: 0.5081 - accuracy: 0.8007 - val_loss: 0.6936 - val_accuracy: 0.7020
#
# Epoch 00020: val_accuracy did not improve from 0.85708
# Epoch 21/50
# 30/30 - 2s - loss: 0.4902 - accuracy: 0.8160 - val_loss: 0.5883 - val_accuracy: 0.7746
#
# Epoch 00021: val_accuracy did not improve from 0.85708
# Epoch 22/50
# 30/30 - 2s - loss: 0.4619 - accuracy: 0.8240 - val_loss: 0.5602 - val_accuracy: 0.7940
#
# Epoch 00022: val_accuracy did not improve from 0.85708
# Epoch 23/50
# 30/30 - 2s - loss: 0.4608 - accuracy: 0.8240 - val_loss: 0.5999 - val_accuracy: 0.7687
#
# Epoch 00023: val_accuracy did not improve from 0.85708
# Epoch 24/50
# 30/30 - 2s - loss: 0.4349 - accuracy: 0.8367 - val_loss: 0.5478 - val_accuracy: 0.8021
#
# Epoch 00024: val_accuracy did not improve from 0.85708
# Epoch 25/50
# 30/30 - 2s - loss: 0.4200 - accuracy: 0.8417 - val_loss: 0.5786 - val_accuracy: 0.7935
#
# Epoch 00025: val_accuracy did not improve from 0.85708
# Epoch 26/50
# 30/30 - 2s - loss: 0.4109 - accuracy: 0.8483 - val_loss: 0.5984 - val_accuracy: 0.7863
#
# Epoch 00026: val_accuracy did not improve from 0.85708
# Epoch 27/50
# 30/30 - 2s - loss: 0.3995 - accuracy: 0.8562 - val_loss: 0.5699 - val_accuracy: 0.7976
#
# Epoch 00027: val_accuracy did not improve from 0.85708
# Epoch 28/50
# 30/30 - 2s - loss: 0.3797 - accuracy: 0.8662 - val_loss: 0.5234 - val_accuracy: 0.8170
#
# Epoch 00028: val_accuracy did not improve from 0.85708
# Epoch 29/50
# 30/30 - 2s - loss: 0.3824 - accuracy: 0.8602 - val_loss: 0.5404 - val_accuracy: 0.8088
#
# Epoch 00029: val_accuracy did not improve from 0.85708
# Epoch 30/50
# 30/30 - 2s - loss: 0.3737 - accuracy: 0.8661 - val_loss: 0.5788 - val_accuracy: 0.7971
#
# Epoch 00030: val_accuracy did not improve from 0.85708
# Epoch 31/50
# 30/30 - 2s - loss: 0.3596 - accuracy: 0.8714 - val_loss: 0.5704 - val_accuracy: 0.8016
#
# Epoch 00031: val_accuracy did not improve from 0.85708
# Epoch 32/50
# 30/30 - 2s - loss: 0.3443 - accuracy: 0.8786 - val_loss: 0.5646 - val_accuracy: 0.8061
#
# Epoch 00032: val_accuracy did not improve from 0.85708
# Epoch 33/50
# 30/30 - 2s - loss: 0.3574 - accuracy: 0.8707 - val_loss: 0.5745 - val_accuracy: 0.8030
#
# Epoch 00033: val_accuracy did not improve from 0.85708
# Epoch 34/50
# 30/30 - 2s - loss: 0.3375 - accuracy: 0.8839 - val_loss: 0.5619 - val_accuracy: 0.8052
#
# Epoch 00034: val_accuracy did not improve from 0.85708
# Epoch 35/50
# 30/30 - 2s - loss: 0.3172 - accuracy: 0.8925 - val_loss: 0.5499 - val_accuracy: 0.8138
#
# Epoch 00035: val_accuracy did not improve from 0.85708
# Epoch 36/50
# 30/30 - 2s - loss: 0.3243 - accuracy: 0.8881 - val_loss: 0.6474 - val_accuracy: 0.7822
#
# Epoch 00036: val_accuracy did not improve from 0.85708
# Epoch 37/50
# 30/30 - 2s - loss: 0.3272 - accuracy: 0.8826 - val_loss: 0.5423 - val_accuracy: 0.8246
#
# Epoch 00037: val_accuracy did not improve from 0.85708
# Epoch 38/50
# 30/30 - 2s - loss: 0.3113 - accuracy: 0.8898 - val_loss: 0.5505 - val_accuracy: 0.8246
#
# Epoch 00038: val_accuracy did not improve from 0.85708
# Epoch 39/50
# 30/30 - 2s - loss: 0.3084 - accuracy: 0.8933 - val_loss: 0.5388 - val_accuracy: 0.8228
#
# Epoch 00039: val_accuracy did not improve from 0.85708
# Epoch 40/50
# 30/30 - 2s - loss: 0.2892 - accuracy: 0.9055 - val_loss: 0.5544 - val_accuracy: 0.8255
#
# Epoch 00040: val_accuracy did not improve from 0.85708
# Epoch 41/50
# 30/30 - 2s - loss: 0.2922 - accuracy: 0.8996 - val_loss: 0.7681 - val_accuracy: 0.7444
#
# Epoch 00041: val_accuracy did not improve from 0.85708
# Epoch 42/50
# 30/30 - 2s - loss: 0.2939 - accuracy: 0.9004 - val_loss: 0.5675 - val_accuracy: 0.8183
#
# Epoch 00042: val_accuracy did not improve from 0.85708
# Epoch 43/50
# 30/30 - 2s - loss: 0.2817 - accuracy: 0.9040 - val_loss: 0.5744 - val_accuracy: 0.8179
#
# Epoch 00043: val_accuracy did not improve from 0.85708
# Epoch 44/50
# 30/30 - 2s - loss: 0.2748 - accuracy: 0.9085 - val_loss: 0.6517 - val_accuracy: 0.7917
#
# Epoch 00044: val_accuracy did not improve from 0.85708
# Epoch 45/50
# 30/30 - 2s - loss: 0.2836 - accuracy: 0.9043 - val_loss: 0.5586 - val_accuracy: 0.8287
#
# Epoch 00045: val_accuracy did not improve from 0.85708
# Epoch 46/50
# 30/30 - 2s - loss: 0.2653 - accuracy: 0.9133 - val_loss: 0.5546 - val_accuracy: 0.8354
#
# Epoch 00046: val_accuracy did not improve from 0.85708
# Epoch 47/50
# 30/30 - 2s - loss: 0.2663 - accuracy: 0.9098 - val_loss: 0.5816 - val_accuracy: 0.8201
#
# Epoch 00047: val_accuracy did not improve from 0.85708
# Epoch 48/50
# 30/30 - 2s - loss: 0.2651 - accuracy: 0.9125 - val_loss: 0.6756 - val_accuracy: 0.7858
#
# Epoch 00048: val_accuracy did not improve from 0.85708
# Epoch 49/50
# 30/30 - 2s - loss: 0.2568 - accuracy: 0.9180 - val_loss: 0.6259 - val_accuracy: 0.8084
#
# Epoch 00049: val_accuracy did not improve from 0.85708
# Epoch 50/50
# 30/30 - 2s - loss: 0.2504 - accuracy: 0.9208 - val_loss: 0.5946 - val_accuracy: 0.8206
#
# Epoch 00050: val_accuracy did not improve from 0.85708
# accuracy: 82.06%
# Epoch 1/50
# 30/30 - 9s - loss: 1.2710 - accuracy: 0.4725 - val_loss: 1.2430 - val_accuracy: 0.4702
#
# Epoch 00001: val_accuracy did not improve from 0.85708
# Epoch 2/50
# 30/30 - 2s - loss: 1.2233 - accuracy: 0.4781 - val_loss: 1.2151 - val_accuracy: 0.4702
#
# Epoch 00002: val_accuracy did not improve from 0.85708
# Epoch 3/50
# 30/30 - 2s - loss: 1.1918 - accuracy: 0.4781 - val_loss: 1.1749 - val_accuracy: 0.4702
#
# Epoch 00003: val_accuracy did not improve from 0.85708
# Epoch 4/50
# 30/30 - 2s - loss: 1.1580 - accuracy: 0.4839 - val_loss: 1.1442 - val_accuracy: 0.4748
#
# Epoch 00004: val_accuracy did not improve from 0.85708
# Epoch 5/50
# 30/30 - 2s - loss: 1.1257 - accuracy: 0.5141 - val_loss: 1.1108 - val_accuracy: 0.5194
#
# Epoch 00005: val_accuracy did not improve from 0.85708
# Epoch 6/50
# 30/30 - 2s - loss: 1.0811 - accuracy: 0.5546 - val_loss: 1.0585 - val_accuracy: 0.5748
#
# Epoch 00006: val_accuracy did not improve from 0.85708
# Epoch 7/50
# 30/30 - 2s - loss: 1.0097 - accuracy: 0.6060 - val_loss: 0.9812 - val_accuracy: 0.6267
#
# Epoch 00007: val_accuracy did not improve from 0.85708
# Epoch 8/50
# 30/30 - 2s - loss: 0.9313 - accuracy: 0.6421 - val_loss: 0.9175 - val_accuracy: 0.6380
#
# Epoch 00008: val_accuracy did not improve from 0.85708
# Epoch 9/50
# 30/30 - 2s - loss: 0.8536 - accuracy: 0.6703 - val_loss: 0.9008 - val_accuracy: 0.6519
#
# Epoch 00009: val_accuracy did not improve from 0.85708
# Epoch 10/50
# 30/30 - 2s - loss: 0.7921 - accuracy: 0.6923 - val_loss: 0.8045 - val_accuracy: 0.6655
#
# Epoch 00010: val_accuracy did not improve from 0.85708
# Epoch 11/50
# 30/30 - 2s - loss: 0.7432 - accuracy: 0.7073 - val_loss: 0.7640 - val_accuracy: 0.7011
#
# Epoch 00011: val_accuracy did not improve from 0.85708
# Epoch 12/50
# 30/30 - 2s - loss: 0.6963 - accuracy: 0.7250 - val_loss: 0.7138 - val_accuracy: 0.7385
#
# Epoch 00012: val_accuracy did not improve from 0.85708
# Epoch 13/50
# 30/30 - 2s - loss: 0.6509 - accuracy: 0.7498 - val_loss: 0.7212 - val_accuracy: 0.6889
#
# Epoch 00013: val_accuracy did not improve from 0.85708
# Epoch 14/50
# 30/30 - 2s - loss: 0.6139 - accuracy: 0.7624 - val_loss: 0.7118 - val_accuracy: 0.6876
#
# Epoch 00014: val_accuracy did not improve from 0.85708
# Epoch 15/50
# 30/30 - 2s - loss: 0.5842 - accuracy: 0.7727 - val_loss: 0.6493 - val_accuracy: 0.7358
#
# Epoch 00015: val_accuracy did not improve from 0.85708
# Epoch 16/50
# 30/30 - 2s - loss: 0.5565 - accuracy: 0.7854 - val_loss: 0.6187 - val_accuracy: 0.7561
#
# Epoch 00016: val_accuracy did not improve from 0.85708
# Epoch 17/50
# 30/30 - 2s - loss: 0.5231 - accuracy: 0.8022 - val_loss: 0.5988 - val_accuracy: 0.7683
#
# Epoch 00017: val_accuracy did not improve from 0.85708
# Epoch 18/50
# 30/30 - 2s - loss: 0.4979 - accuracy: 0.8134 - val_loss: 0.5838 - val_accuracy: 0.7764
#
# Epoch 00018: val_accuracy did not improve from 0.85708
# Epoch 19/50
# 30/30 - 2s - loss: 0.4790 - accuracy: 0.8229 - val_loss: 0.6402 - val_accuracy: 0.7358
#
# Epoch 00019: val_accuracy did not improve from 0.85708
# Epoch 20/50
# 30/30 - 2s - loss: 0.4605 - accuracy: 0.8327 - val_loss: 0.5440 - val_accuracy: 0.8012
#
# Epoch 00020: val_accuracy did not improve from 0.85708
# Epoch 21/50
# 30/30 - 2s - loss: 0.4431 - accuracy: 0.8403 - val_loss: 0.5316 - val_accuracy: 0.8066
#
# Epoch 00021: val_accuracy did not improve from 0.85708
# Epoch 22/50
# 30/30 - 2s - loss: 0.4188 - accuracy: 0.8508 - val_loss: 0.5918 - val_accuracy: 0.7800
#
# Epoch 00022: val_accuracy did not improve from 0.85708
# Epoch 23/50
# 30/30 - 2s - loss: 0.4120 - accuracy: 0.8481 - val_loss: 0.5185 - val_accuracy: 0.8129
#
# Epoch 00023: val_accuracy did not improve from 0.85708
# Epoch 24/50
# 30/30 - 2s - loss: 0.4002 - accuracy: 0.8556 - val_loss: 0.5258 - val_accuracy: 0.8034
#
# Epoch 00024: val_accuracy did not improve from 0.85708
# Epoch 25/50
# 30/30 - 2s - loss: 0.3809 - accuracy: 0.8649 - val_loss: 0.5857 - val_accuracy: 0.7701
#
# Epoch 00025: val_accuracy did not improve from 0.85708
# Epoch 26/50
# 30/30 - 2s - loss: 0.3683 - accuracy: 0.8701 - val_loss: 0.7177 - val_accuracy: 0.7394
#
# Epoch 00026: val_accuracy did not improve from 0.85708
# Epoch 27/50
# 30/30 - 2s - loss: 0.3750 - accuracy: 0.8652 - val_loss: 0.5420 - val_accuracy: 0.8093
#
# Epoch 00027: val_accuracy did not improve from 0.85708
# Epoch 28/50
# 30/30 - 2s - loss: 0.3610 - accuracy: 0.8732 - val_loss: 0.4897 - val_accuracy: 0.8332
#
# Epoch 00028: val_accuracy did not improve from 0.85708
# Epoch 29/50
# 30/30 - 2s - loss: 0.3499 - accuracy: 0.8785 - val_loss: 0.5495 - val_accuracy: 0.8097
#
# Epoch 00029: val_accuracy did not improve from 0.85708
# Epoch 30/50
# 30/30 - 2s - loss: 0.3421 - accuracy: 0.8824 - val_loss: 0.5438 - val_accuracy: 0.7967
#
# Epoch 00030: val_accuracy did not improve from 0.85708
# Epoch 31/50
# 30/30 - 2s - loss: 0.3339 - accuracy: 0.8830 - val_loss: 0.5421 - val_accuracy: 0.7971
#
# Epoch 00031: val_accuracy did not improve from 0.85708
# Epoch 32/50
# 30/30 - 2s - loss: 0.3273 - accuracy: 0.8861 - val_loss: 0.5689 - val_accuracy: 0.7831
#
# Epoch 00032: val_accuracy did not improve from 0.85708
# Epoch 33/50
# 30/30 - 2s - loss: 0.3151 - accuracy: 0.8952 - val_loss: 0.5026 - val_accuracy: 0.8368
#
# Epoch 00033: val_accuracy did not improve from 0.85708
# Epoch 34/50
# 30/30 - 2s - loss: 0.3127 - accuracy: 0.9004 - val_loss: 0.4896 - val_accuracy: 0.8413
#
# Epoch 00034: val_accuracy did not improve from 0.85708
# Epoch 35/50
# 30/30 - 2s - loss: 0.3028 - accuracy: 0.8995 - val_loss: 0.4899 - val_accuracy: 0.8413
#
# Epoch 00035: val_accuracy did not improve from 0.85708
# Epoch 36/50
# 30/30 - 2s - loss: 0.2950 - accuracy: 0.9049 - val_loss: 0.5543 - val_accuracy: 0.7971
#
# Epoch 00036: val_accuracy did not improve from 0.85708
# Epoch 37/50
# 30/30 - 2s - loss: 0.2989 - accuracy: 0.8993 - val_loss: 0.5338 - val_accuracy: 0.8129
#
# Epoch 00037: val_accuracy did not improve from 0.85708
# Epoch 38/50
# 30/30 - 2s - loss: 0.2966 - accuracy: 0.8991 - val_loss: 0.5394 - val_accuracy: 0.8255
#
# Epoch 00038: val_accuracy did not improve from 0.85708
# Epoch 39/50
# 30/30 - 2s - loss: 0.2811 - accuracy: 0.9084 - val_loss: 0.5266 - val_accuracy: 0.8309
#
# Epoch 00039: val_accuracy did not improve from 0.85708
# Epoch 40/50
# 30/30 - 2s - loss: 0.2829 - accuracy: 0.9058 - val_loss: 0.5199 - val_accuracy: 0.8341
#
# Epoch 00040: val_accuracy did not improve from 0.85708
# Epoch 41/50
# 30/30 - 2s - loss: 0.2747 - accuracy: 0.9129 - val_loss: 0.5173 - val_accuracy: 0.8381
#
# Epoch 00041: val_accuracy did not improve from 0.85708
# Epoch 42/50
# 30/30 - 2s - loss: 0.2710 - accuracy: 0.9095 - val_loss: 0.5659 - val_accuracy: 0.8183
#
# Epoch 00042: val_accuracy did not improve from 0.85708
# Epoch 43/50
# 30/30 - 2s - loss: 0.2665 - accuracy: 0.9144 - val_loss: 0.7310 - val_accuracy: 0.7399
#
# Epoch 00043: val_accuracy did not improve from 0.85708
# Epoch 44/50
# 30/30 - 2s - loss: 0.2527 - accuracy: 0.9213 - val_loss: 0.5147 - val_accuracy: 0.8413
#
# Epoch 00044: val_accuracy did not improve from 0.85708
# Epoch 45/50
# 30/30 - 2s - loss: 0.2541 - accuracy: 0.9226 - val_loss: 0.5307 - val_accuracy: 0.8363
#
# Epoch 00045: val_accuracy did not improve from 0.85708
# Epoch 46/50
# 30/30 - 2s - loss: 0.2499 - accuracy: 0.9213 - val_loss: 0.7135 - val_accuracy: 0.7498
#
# Epoch 00046: val_accuracy did not improve from 0.85708
# Epoch 47/50
# 30/30 - 2s - loss: 0.2561 - accuracy: 0.9208 - val_loss: 0.8967 - val_accuracy: 0.7020
#
# Epoch 00047: val_accuracy did not improve from 0.85708
# Epoch 48/50
# 30/30 - 2s - loss: 0.2504 - accuracy: 0.9227 - val_loss: 0.5615 - val_accuracy: 0.8314
#
# Epoch 00048: val_accuracy did not improve from 0.85708
# Epoch 49/50
# 30/30 - 2s - loss: 0.2430 - accuracy: 0.9237 - val_loss: 0.5278 - val_accuracy: 0.8431
#
# Epoch 00049: val_accuracy did not improve from 0.85708
# Epoch 50/50
# 30/30 - 2s - loss: 0.2339 - accuracy: 0.9272 - val_loss: 0.5584 - val_accuracy: 0.8201
#
# Epoch 00050: val_accuracy did not improve from 0.85708
# accuracy: 82.01%
# Epoch 1/50
# 30/30 - 9s - loss: 1.2748 - accuracy: 0.4705 - val_loss: 1.2461 - val_accuracy: 0.4748
#
# Epoch 00001: val_accuracy did not improve from 0.85708
# Epoch 2/50
# 30/30 - 2s - loss: 1.2286 - accuracy: 0.4776 - val_loss: 1.2223 - val_accuracy: 0.4748
#
# Epoch 00002: val_accuracy did not improve from 0.85708
# Epoch 3/50
# 30/30 - 2s - loss: 1.2069 - accuracy: 0.4776 - val_loss: 1.1980 - val_accuracy: 0.4748
#
# Epoch 00003: val_accuracy did not improve from 0.85708
# Epoch 4/50
# 30/30 - 2s - loss: 1.1743 - accuracy: 0.4776 - val_loss: 1.1635 - val_accuracy: 0.4748
#
# Epoch 00004: val_accuracy did not improve from 0.85708
# Epoch 5/50
# 30/30 - 2s - loss: 1.1450 - accuracy: 0.4794 - val_loss: 1.1437 - val_accuracy: 0.4748
#
# Epoch 00005: val_accuracy did not improve from 0.85708
# Epoch 6/50
# 30/30 - 2s - loss: 1.1191 - accuracy: 0.4993 - val_loss: 1.1183 - val_accuracy: 0.4829
#
# Epoch 00006: val_accuracy did not improve from 0.85708
# Epoch 7/50
# 30/30 - 2s - loss: 1.0856 - accuracy: 0.5362 - val_loss: 1.0841 - val_accuracy: 0.5203
#
# Epoch 00007: val_accuracy did not improve from 0.85708
# Epoch 8/50
# 30/30 - 2s - loss: 1.0380 - accuracy: 0.5785 - val_loss: 1.0278 - val_accuracy: 0.5821
#
# Epoch 00008: val_accuracy did not improve from 0.85708
# Epoch 9/50
# 30/30 - 2s - loss: 0.9691 - accuracy: 0.6201 - val_loss: 0.9768 - val_accuracy: 0.5915
#
# Epoch 00009: val_accuracy did not improve from 0.85708
# Epoch 10/50
# 30/30 - 2s - loss: 0.8928 - accuracy: 0.6519 - val_loss: 0.8939 - val_accuracy: 0.6425
#
# Epoch 00010: val_accuracy did not improve from 0.85708
# Epoch 11/50
# 30/30 - 2s - loss: 0.8154 - accuracy: 0.6777 - val_loss: 0.8411 - val_accuracy: 0.6682
#
# Epoch 00011: val_accuracy did not improve from 0.85708
# Epoch 12/50
# 30/30 - 2s - loss: 0.7643 - accuracy: 0.6939 - val_loss: 0.8583 - val_accuracy: 0.6483
#
# Epoch 00012: val_accuracy did not improve from 0.85708
# Epoch 13/50
# 30/30 - 2s - loss: 0.7059 - accuracy: 0.7189 - val_loss: 0.7792 - val_accuracy: 0.6997
#
# Epoch 00013: val_accuracy did not improve from 0.85708
# Epoch 14/50
# 30/30 - 2s - loss: 0.6591 - accuracy: 0.7418 - val_loss: 0.7756 - val_accuracy: 0.6934
#
# Epoch 00014: val_accuracy did not improve from 0.85708
# Epoch 15/50
# 30/30 - 2s - loss: 0.6230 - accuracy: 0.7568 - val_loss: 0.7526 - val_accuracy: 0.7024
#
# Epoch 00015: val_accuracy did not improve from 0.85708
# Epoch 16/50
# 30/30 - 2s - loss: 0.5924 - accuracy: 0.7675 - val_loss: 0.6861 - val_accuracy: 0.7421
#
# Epoch 00016: val_accuracy did not improve from 0.85708
# Epoch 17/50
# 30/30 - 2s - loss: 0.5556 - accuracy: 0.7908 - val_loss: 0.6236 - val_accuracy: 0.7529
#
# Epoch 00017: val_accuracy did not improve from 0.85708
# Epoch 18/50
# 30/30 - 2s - loss: 0.5289 - accuracy: 0.8004 - val_loss: 0.6732 - val_accuracy: 0.7178
#
# Epoch 00018: val_accuracy did not improve from 0.85708
# Epoch 19/50
# 30/30 - 2s - loss: 0.5116 - accuracy: 0.8013 - val_loss: 0.5959 - val_accuracy: 0.7615
#
# Epoch 00019: val_accuracy did not improve from 0.85708
# Epoch 20/50
# 30/30 - 2s - loss: 0.4865 - accuracy: 0.8139 - val_loss: 0.5807 - val_accuracy: 0.7719
#
# Epoch 00020: val_accuracy did not improve from 0.85708
# Epoch 21/50
# 30/30 - 2s - loss: 0.4680 - accuracy: 0.8240 - val_loss: 0.5802 - val_accuracy: 0.7678
#
# Epoch 00021: val_accuracy did not improve from 0.85708
# Epoch 22/50
# 30/30 - 2s - loss: 0.4498 - accuracy: 0.8309 - val_loss: 0.5541 - val_accuracy: 0.7836
#
# Epoch 00022: val_accuracy did not improve from 0.85708
# Epoch 23/50
# 30/30 - 2s - loss: 0.4235 - accuracy: 0.8459 - val_loss: 0.5344 - val_accuracy: 0.8057
#
# Epoch 00023: val_accuracy did not improve from 0.85708
# Epoch 24/50
# 30/30 - 2s - loss: 0.4215 - accuracy: 0.8409 - val_loss: 0.5412 - val_accuracy: 0.7881
#
# Epoch 00024: val_accuracy did not improve from 0.85708
# Epoch 25/50
# 30/30 - 2s - loss: 0.4033 - accuracy: 0.8506 - val_loss: 0.5598 - val_accuracy: 0.7958
#
# Epoch 00025: val_accuracy did not improve from 0.85708
# Epoch 26/50
# 30/30 - 2s - loss: 0.3837 - accuracy: 0.8625 - val_loss: 0.6351 - val_accuracy: 0.7665
#
# Epoch 00026: val_accuracy did not improve from 0.85708
# Epoch 27/50
# 30/30 - 2s - loss: 0.3791 - accuracy: 0.8589 - val_loss: 0.5761 - val_accuracy: 0.7836
#
# Epoch 00027: val_accuracy did not improve from 0.85708
# Epoch 28/50
# 30/30 - 2s - loss: 0.3634 - accuracy: 0.8732 - val_loss: 0.5131 - val_accuracy: 0.8170
#
# Epoch 00028: val_accuracy did not improve from 0.85708
# Epoch 29/50
# 30/30 - 2s - loss: 0.3590 - accuracy: 0.8723 - val_loss: 0.5041 - val_accuracy: 0.8233
#
# Epoch 00029: val_accuracy did not improve from 0.85708
# Epoch 30/50
# 30/30 - 2s - loss: 0.3391 - accuracy: 0.8818 - val_loss: 0.5279 - val_accuracy: 0.8012
#
# Epoch 00030: val_accuracy did not improve from 0.85708
# Epoch 31/50
# 30/30 - 2s - loss: 0.3356 - accuracy: 0.8817 - val_loss: 0.5831 - val_accuracy: 0.7840
#
# Epoch 00031: val_accuracy did not improve from 0.85708
# Epoch 32/50
# 30/30 - 2s - loss: 0.3325 - accuracy: 0.8813 - val_loss: 0.5727 - val_accuracy: 0.7867
#
# Epoch 00032: val_accuracy did not improve from 0.85708
# Epoch 33/50
# 30/30 - 2s - loss: 0.3144 - accuracy: 0.8917 - val_loss: 0.5546 - val_accuracy: 0.7994
#
# Epoch 00033: val_accuracy did not improve from 0.85708
# Epoch 34/50
# 30/30 - 2s - loss: 0.3065 - accuracy: 0.8962 - val_loss: 0.5213 - val_accuracy: 0.8129
#
# Epoch 00034: val_accuracy did not improve from 0.85708
# Epoch 35/50
# 30/30 - 2s - loss: 0.3028 - accuracy: 0.8970 - val_loss: 0.5577 - val_accuracy: 0.7913
#
# Epoch 00035: val_accuracy did not improve from 0.85708
# Epoch 36/50
# 30/30 - 2s - loss: 0.2994 - accuracy: 0.8981 - val_loss: 0.4987 - val_accuracy: 0.8273
#
# Epoch 00036: val_accuracy did not improve from 0.85708
# Epoch 37/50
# 30/30 - 2s - loss: 0.2936 - accuracy: 0.8986 - val_loss: 0.5134 - val_accuracy: 0.8201
#
# Epoch 00037: val_accuracy did not improve from 0.85708
# Epoch 38/50
# 30/30 - 2s - loss: 0.2763 - accuracy: 0.9086 - val_loss: 0.4907 - val_accuracy: 0.8436
#
# Epoch 00038: val_accuracy did not improve from 0.85708
# Epoch 39/50
# 30/30 - 2s - loss: 0.2789 - accuracy: 0.9100 - val_loss: 0.5124 - val_accuracy: 0.8251
#
# Epoch 00039: val_accuracy did not improve from 0.85708
# Epoch 40/50
# 30/30 - 2s - loss: 0.2764 - accuracy: 0.9048 - val_loss: 0.5698 - val_accuracy: 0.8021
#
# Epoch 00040: val_accuracy did not improve from 0.85708
# Epoch 41/50
# 30/30 - 2s - loss: 0.2661 - accuracy: 0.9123 - val_loss: 0.4894 - val_accuracy: 0.8445
#
# Epoch 00041: val_accuracy did not improve from 0.85708
# Epoch 42/50
# 30/30 - 2s - loss: 0.2610 - accuracy: 0.9118 - val_loss: 0.5663 - val_accuracy: 0.8088
#
# Epoch 00042: val_accuracy did not improve from 0.85708
# Epoch 43/50
# 30/30 - 2s - loss: 0.2515 - accuracy: 0.9175 - val_loss: 0.6139 - val_accuracy: 0.7994
#
# Epoch 00043: val_accuracy did not improve from 0.85708
# Epoch 44/50
# 30/30 - 2s - loss: 0.2484 - accuracy: 0.9189 - val_loss: 0.5011 - val_accuracy: 0.8399
#
# Epoch 00044: val_accuracy did not improve from 0.85708
# Epoch 45/50
# 30/30 - 2s - loss: 0.2410 - accuracy: 0.9193 - val_loss: 0.4974 - val_accuracy: 0.8399
#
# Epoch 00045: val_accuracy did not improve from 0.85708
# Epoch 46/50
# 30/30 - 2s - loss: 0.2309 - accuracy: 0.9263 - val_loss: 0.5809 - val_accuracy: 0.8066
#
# Epoch 00046: val_accuracy did not improve from 0.85708
# Epoch 47/50
# 30/30 - 2s - loss: 0.2338 - accuracy: 0.9261 - val_loss: 0.5129 - val_accuracy: 0.8408
#
# Epoch 00047: val_accuracy did not improve from 0.85708
# Epoch 48/50
# 30/30 - 2s - loss: 0.2274 - accuracy: 0.9310 - val_loss: 0.5201 - val_accuracy: 0.8472
#
# Epoch 00048: val_accuracy did not improve from 0.85708
# Epoch 49/50
# 30/30 - 2s - loss: 0.2256 - accuracy: 0.9307 - val_loss: 0.5179 - val_accuracy: 0.8508
#
# Epoch 00049: val_accuracy did not improve from 0.85708
# Epoch 50/50
# 30/30 - 2s - loss: 0.2090 - accuracy: 0.9344 - val_loss: 0.5299 - val_accuracy: 0.8386
#
# Epoch 00050: val_accuracy did not improve from 0.85708
# accuracy: 83.86%
# 82.99% (+/- 1.43%)

# %%
# Menampilkan plot loss dari model
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])
plt.show()

# %%
# Menampilkan plot akurasi dari model
plt.plot(history2.history['accuracy'])
plt.plot(history2.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'validation'])
plt.show()

# %%
loss, acc = model.evaluate(padded_test2, y_test, verbose=1)
                            #batch_size=batch_size)
print("loss:", loss)
print("Validation accuracy:", acc)
# Out:
# 70/70 [==============================] - 0s 6ms/step - loss: 0.5299 - accuracy: 0.8386
# loss: 0.5298528671264648
# Validation accuracy: 0.8385933041572571

# %%
def model_evaluate2(): 
    # predict class with test set
    y_pred_test =  model.predict_classes(padded_test2, verbose=0)
    print('Accuracy:\t{:0.1f}%'.format(accuracy_score(np.argmax(y_test,axis=1),y_pred_test)*100))
    
    #classification report
    print('\n')
    print(classification_report(np.argmax(y_test,axis=1), y_pred_test))

    #confusion matrix
    confmat = confusion_matrix(np.argmax(y_test,axis=1), y_pred_test)

    fig, ax = plt.subplots(figsize=(4, 4))
    ax.matshow(confmat, cmap=plt.cm.Blues, alpha=0.3)
    for i in range(confmat.shape[0]):
        for j in range(confmat.shape[1]):
            ax.text(x=j, y=i, s=confmat[i, j], va='center', ha='center')
    plt.xlabel('Predicted label')
    plt.ylabel('True label')
    plt.tight_layout()

model_evaluate2()
# Out:
# C:\Users\Alfa\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\keras\engine\sequential.py:455: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# Accuracy:	83.9%
#
#
#               precision    recall  f1-score   support
#
#            0       0.92      0.88      0.90      1053
#            1       0.67      0.66      0.67       513
#            2       0.84      0.90      0.87       652
#
#     accuracy                           0.84      2218
#    macro avg       0.81      0.82      0.81      2218
# weighted avg       0.84      0.84      0.84      2218

# %%
for train, test in kfold.split(x_train,y_train):
       
    # Membuat model Sequential dengan Bidirectional LSTM
    model = tf.keras.Sequential([
    tf.keras.layers.Embedding(6500, 32), # 6500 input & 32 layer embedding
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64,  return_sequences=True)), # 64 layer LSTM
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)), # 32 layer LSTM
    tf.keras.layers.Dense(128, activation='relu'), # Menambah layer dan menggunakan relu sebagai fungsi aktivasi
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(512, kernel_regularizer=regularizers.l2(0.001), activation='relu'), #kernel_regularizer=regularizers.l2(0.0001),
    tf.keras.layers.Dropout(0.5), # Menggunakan dropout agar model tidak overfitting
    tf.keras.layers.Dense(3, activation='softmax') # Outputnya adalah 3 dan karena kategorikal menggunakan aktivasi softmax
    ])

    #model.summary() # Melihat shape dan parameter model
    model.compile(loss='categorical_crossentropy', optimizer=RMSprop(learning_rate=0.0001),metrics=['accuracy']) # Menggunakan optimizer RMSprop dengan learning rate 0.0001
    history2 = model.fit(padded_latih, y_train, validation_data=(padded_test, y_test), epochs=50,#batch_size=batch_size,
                    steps_per_epoch= 30, callbacks=[checkpoint], verbose=2)
    evalcross = model.evaluate(padded_test, y_test, verbose=0)
    print("%s: %.2f%%" % (model.metrics_names[1], evalcross[1]*100))
    cvscores.append(evalcross[1] * 100)
print("%.2f%% (+/- %.2f%%)" % (np.mean(cvscores), np.std(cvscores)))
# Out:
# Epoch 1/50
# 30/30 - 8s - loss: 1.2727 - accuracy: 0.4697 - val_loss: 1.2402 - val_accuracy: 0.4815
#
# Epoch 00001: val_accuracy did not improve from 0.85708
# Epoch 2/50
# 30/30 - 2s - loss: 1.2274 - accuracy: 0.4768 - val_loss: 1.2137 - val_accuracy: 0.4815
#
# Epoch 00002: val_accuracy did not improve from 0.85708
# Epoch 3/50
# 30/30 - 2s - loss: 1.2004 - accuracy: 0.4768 - val_loss: 1.1798 - val_accuracy: 0.4815
#
# Epoch 00003: val_accuracy did not improve from 0.85708
# Epoch 4/50
# 30/30 - 2s - loss: 1.1616 - accuracy: 0.4772 - val_loss: 1.1425 - val_accuracy: 0.4811
#
# Epoch 00004: val_accuracy did not improve from 0.85708
# Epoch 5/50
# 30/30 - 2s - loss: 1.1270 - accuracy: 0.5097 - val_loss: 1.1086 - val_accuracy: 0.5325
#
# Epoch 00005: val_accuracy did not improve from 0.85708
# Epoch 6/50
# 30/30 - 2s - loss: 1.0853 - accuracy: 0.5442 - val_loss: 1.0649 - val_accuracy: 0.5550
#
# Epoch 00006: val_accuracy did not improve from 0.85708
# Epoch 7/50
# 30/30 - 2s - loss: 1.0199 - accuracy: 0.5908 - val_loss: 0.9771 - val_accuracy: 0.6235
#
# Epoch 00007: val_accuracy did not improve from 0.85708
# Epoch 8/50
# 30/30 - 2s - loss: 0.9395 - accuracy: 0.6380 - val_loss: 0.9009 - val_accuracy: 0.6528
#
# Epoch 00008: val_accuracy did not improve from 0.85708
# Epoch 9/50
# 30/30 - 2s - loss: 0.8626 - accuracy: 0.6699 - val_loss: 0.8465 - val_accuracy: 0.6583
#
# Epoch 00009: val_accuracy did not improve from 0.85708
# Epoch 10/50
# 30/30 - 2s - loss: 0.7942 - accuracy: 0.6924 - val_loss: 0.7831 - val_accuracy: 0.6930
#
# Epoch 00010: val_accuracy did not improve from 0.85708
# Epoch 11/50
# 30/30 - 2s - loss: 0.7333 - accuracy: 0.7160 - val_loss: 0.7779 - val_accuracy: 0.6826
#
# Epoch 00011: val_accuracy did not improve from 0.85708
# Epoch 12/50
# 30/30 - 2s - loss: 0.6906 - accuracy: 0.7351 - val_loss: 0.7664 - val_accuracy: 0.6826
#
# Epoch 00012: val_accuracy did not improve from 0.85708
# Epoch 13/50
# 30/30 - 2s - loss: 0.6527 - accuracy: 0.7490 - val_loss: 0.6472 - val_accuracy: 0.7484
#
# Epoch 00013: val_accuracy did not improve from 0.85708
# Epoch 14/50
# 30/30 - 2s - loss: 0.6180 - accuracy: 0.7620 - val_loss: 0.6198 - val_accuracy: 0.7660
#
# Epoch 00014: val_accuracy did not improve from 0.85708
# Epoch 15/50
# 30/30 - 2s - loss: 0.5827 - accuracy: 0.7818 - val_loss: 0.6012 - val_accuracy: 0.7732
#
# Epoch 00015: val_accuracy did not improve from 0.85708
# Epoch 16/50
# 30/30 - 2s - loss: 0.5606 - accuracy: 0.7884 - val_loss: 0.5925 - val_accuracy: 0.7705
#
# Epoch 00016: val_accuracy did not improve from 0.85708
# Epoch 17/50
# 30/30 - 2s - loss: 0.5288 - accuracy: 0.8025 - val_loss: 0.5806 - val_accuracy: 0.7795
#
# Epoch 00017: val_accuracy did not improve from 0.85708
# Epoch 18/50
# 30/30 - 2s - loss: 0.5144 - accuracy: 0.8111 - val_loss: 0.5738 - val_accuracy: 0.7840
#
# Epoch 00018: val_accuracy did not improve from 0.85708
# Epoch 19/50
# 30/30 - 2s - loss: 0.4869 - accuracy: 0.8190 - val_loss: 0.5348 - val_accuracy: 0.8147
#
# Epoch 00019: val_accuracy did not improve from 0.85708
# Epoch 20/50
# 30/30 - 2s - loss: 0.4690 - accuracy: 0.8275 - val_loss: 0.5268 - val_accuracy: 0.8165
#
# Epoch 00020: val_accuracy did not improve from 0.85708
# Epoch 21/50
# 30/30 - 2s - loss: 0.4491 - accuracy: 0.8361 - val_loss: 0.5340 - val_accuracy: 0.8070
#
# Epoch 00021: val_accuracy did not improve from 0.85708
# Epoch 22/50
# 30/30 - 2s - loss: 0.4490 - accuracy: 0.8334 - val_loss: 0.5118 - val_accuracy: 0.8165
#
# Epoch 00022: val_accuracy did not improve from 0.85708
# Epoch 23/50
# 30/30 - 2s - loss: 0.4203 - accuracy: 0.8484 - val_loss: 0.5401 - val_accuracy: 0.8111
#
# Epoch 00023: val_accuracy did not improve from 0.85708
# Epoch 24/50
# 30/30 - 2s - loss: 0.4104 - accuracy: 0.8513 - val_loss: 0.5019 - val_accuracy: 0.8251
#
# Epoch 00024: val_accuracy did not improve from 0.85708
# Epoch 25/50
# 30/30 - 2s - loss: 0.3970 - accuracy: 0.8623 - val_loss: 0.5882 - val_accuracy: 0.7791
#
# Epoch 00025: val_accuracy did not improve from 0.85708
# Epoch 26/50
# 30/30 - 2s - loss: 0.3890 - accuracy: 0.8632 - val_loss: 0.6622 - val_accuracy: 0.7552
#
# Epoch 00026: val_accuracy did not improve from 0.85708
# Epoch 27/50
# 30/30 - 2s - loss: 0.3767 - accuracy: 0.8688 - val_loss: 0.7135 - val_accuracy: 0.7335
#
# Epoch 00027: val_accuracy did not improve from 0.85708
# Epoch 28/50
# 30/30 - 2s - loss: 0.3683 - accuracy: 0.8739 - val_loss: 0.6690 - val_accuracy: 0.7565
#
# Epoch 00028: val_accuracy did not improve from 0.85708
# Epoch 29/50
# 30/30 - 2s - loss: 0.3556 - accuracy: 0.8755 - val_loss: 0.5659 - val_accuracy: 0.7940
#
# Epoch 00029: val_accuracy did not improve from 0.85708
# Epoch 30/50
# 30/30 - 2s - loss: 0.3512 - accuracy: 0.8806 - val_loss: 0.5136 - val_accuracy: 0.8345
#
# Epoch 00030: val_accuracy did not improve from 0.85708
# Epoch 31/50
# 30/30 - 2s - loss: 0.3404 - accuracy: 0.8846 - val_loss: 0.4912 - val_accuracy: 0.8417
#
# Epoch 00031: val_accuracy did not improve from 0.85708
# Epoch 32/50
# 30/30 - 2s - loss: 0.3255 - accuracy: 0.8888 - val_loss: 0.4960 - val_accuracy: 0.8381
#
# Epoch 00032: val_accuracy did not improve from 0.85708
# Epoch 33/50
# 30/30 - 2s - loss: 0.3355 - accuracy: 0.8843 - val_loss: 0.4955 - val_accuracy: 0.8372
#
# Epoch 00033: val_accuracy did not improve from 0.85708
# Epoch 34/50
# 30/30 - 2s - loss: 0.3226 - accuracy: 0.8909 - val_loss: 0.4934 - val_accuracy: 0.8399
#
# Epoch 00034: val_accuracy did not improve from 0.85708
# Epoch 35/50
# 30/30 - 2s - loss: 0.3146 - accuracy: 0.8947 - val_loss: 0.5032 - val_accuracy: 0.8372
#
# Epoch 00035: val_accuracy did not improve from 0.85708
# Epoch 36/50
# 30/30 - 2s - loss: 0.3033 - accuracy: 0.9015 - val_loss: 0.5382 - val_accuracy: 0.8228
#
# Epoch 00036: val_accuracy did not improve from 0.85708
# Epoch 37/50
# 30/30 - 2s - loss: 0.3059 - accuracy: 0.8957 - val_loss: 0.4947 - val_accuracy: 0.8417
#
# Epoch 00037: val_accuracy did not improve from 0.85708
# Epoch 38/50
# 30/30 - 2s - loss: 0.2986 - accuracy: 0.9043 - val_loss: 0.5308 - val_accuracy: 0.8305
#
# Epoch 00038: val_accuracy did not improve from 0.85708
# Epoch 39/50
# 30/30 - 2s - loss: 0.2882 - accuracy: 0.9068 - val_loss: 0.6557 - val_accuracy: 0.7845
#
# Epoch 00039: val_accuracy did not improve from 0.85708
# Epoch 40/50
# 30/30 - 2s - loss: 0.2857 - accuracy: 0.9099 - val_loss: 0.5662 - val_accuracy: 0.8215
#
# Epoch 00040: val_accuracy did not improve from 0.85708
# Epoch 41/50
# 30/30 - 2s - loss: 0.2863 - accuracy: 0.9057 - val_loss: 0.5305 - val_accuracy: 0.8332
#
# Epoch 00041: val_accuracy did not improve from 0.85708
# Epoch 42/50
# 30/30 - 2s - loss: 0.2773 - accuracy: 0.9129 - val_loss: 0.5913 - val_accuracy: 0.8097
#
# Epoch 00042: val_accuracy did not improve from 0.85708
# Epoch 43/50
# 30/30 - 2s - loss: 0.2686 - accuracy: 0.9130 - val_loss: 0.7149 - val_accuracy: 0.7723
#
# Epoch 00043: val_accuracy did not improve from 0.85708
# Epoch 44/50
# 30/30 - 2s - loss: 0.2554 - accuracy: 0.9237 - val_loss: 0.6343 - val_accuracy: 0.8048
#
# Epoch 00044: val_accuracy did not improve from 0.85708
# Epoch 45/50
# 30/30 - 2s - loss: 0.2722 - accuracy: 0.9119 - val_loss: 0.5285 - val_accuracy: 0.8454
#
# Epoch 00045: val_accuracy did not improve from 0.85708
# Epoch 46/50
# 30/30 - 2s - loss: 0.2606 - accuracy: 0.9164 - val_loss: 0.6351 - val_accuracy: 0.7953
#
# Epoch 00046: val_accuracy did not improve from 0.85708
# Epoch 47/50
# 30/30 - 2s - loss: 0.2486 - accuracy: 0.9235 - val_loss: 0.5309 - val_accuracy: 0.8458
#
# Epoch 00047: val_accuracy did not improve from 0.85708
# Epoch 48/50
# 30/30 - 2s - loss: 0.2473 - accuracy: 0.9224 - val_loss: 0.5261 - val_accuracy: 0.8548
#
# Epoch 00048: val_accuracy did not improve from 0.85708
# Epoch 49/50
# 30/30 - 2s - loss: 0.2395 - accuracy: 0.9270 - val_loss: 0.5358 - val_accuracy: 0.8526
#
# Epoch 00049: val_accuracy did not improve from 0.85708
# Epoch 50/50
# 30/30 - 2s - loss: 0.2418 - accuracy: 0.9244 - val_loss: 0.5527 - val_accuracy: 0.8395
#
# Epoch 00050: val_accuracy did not improve from 0.85708
# accuracy: 83.95%
# Epoch 1/50
# 30/30 - 9s - loss: 1.2714 - accuracy: 0.4717 - val_loss: 1.2397 - val_accuracy: 0.4815
#
# Epoch 00001: val_accuracy did not improve from 0.85708
# Epoch 2/50
# 30/30 - 2s - loss: 1.2287 - accuracy: 0.4768 - val_loss: 1.2165 - val_accuracy: 0.4815
#
# Epoch 00002: val_accuracy did not improve from 0.85708
# Epoch 3/50
# 30/30 - 2s - loss: 1.2056 - accuracy: 0.4768 - val_loss: 1.1883 - val_accuracy: 0.4815
#
# Epoch 00003: val_accuracy did not improve from 0.85708
# Epoch 4/50
# 30/30 - 2s - loss: 1.1710 - accuracy: 0.4769 - val_loss: 1.1510 - val_accuracy: 0.4815
#
# Epoch 00004: val_accuracy did not improve from 0.85708
# Epoch 5/50
# 30/30 - 2s - loss: 1.1374 - accuracy: 0.4809 - val_loss: 1.1202 - val_accuracy: 0.5054
#
# Epoch 00005: val_accuracy did not improve from 0.85708
# Epoch 6/50
# 30/30 - 2s - loss: 1.1013 - accuracy: 0.5174 - val_loss: 1.0737 - val_accuracy: 0.5415
#
# Epoch 00006: val_accuracy did not improve from 0.85708
# Epoch 7/50
# 30/30 - 2s - loss: 1.0432 - accuracy: 0.5659 - val_loss: 1.0046 - val_accuracy: 0.6127
#
# Epoch 00007: val_accuracy did not improve from 0.85708
# Epoch 8/50
# 30/30 - 2s - loss: 0.9702 - accuracy: 0.6238 - val_loss: 0.9407 - val_accuracy: 0.6429
#
# Epoch 00008: val_accuracy did not improve from 0.85708
# Epoch 9/50
# 30/30 - 2s - loss: 0.8980 - accuracy: 0.6576 - val_loss: 0.8642 - val_accuracy: 0.6749
#
# Epoch 00009: val_accuracy did not improve from 0.85708
# Epoch 10/50
# 30/30 - 2s - loss: 0.8241 - accuracy: 0.6817 - val_loss: 0.8089 - val_accuracy: 0.6826
#
# Epoch 00010: val_accuracy did not improve from 0.85708
# Epoch 11/50
# 30/30 - 2s - loss: 0.7652 - accuracy: 0.7025 - val_loss: 0.7607 - val_accuracy: 0.7128
#
# Epoch 00011: val_accuracy did not improve from 0.85708
# Epoch 12/50
# 30/30 - 2s - loss: 0.7129 - accuracy: 0.7175 - val_loss: 0.7276 - val_accuracy: 0.7200
#
# Epoch 00012: val_accuracy did not improve from 0.85708
# Epoch 13/50
# 30/30 - 2s - loss: 0.6683 - accuracy: 0.7386 - val_loss: 0.6794 - val_accuracy: 0.7462
#
# Epoch 00013: val_accuracy did not improve from 0.85708
# Epoch 14/50
# 30/30 - 2s - loss: 0.6288 - accuracy: 0.7547 - val_loss: 0.6695 - val_accuracy: 0.7502
#
# Epoch 00014: val_accuracy did not improve from 0.85708
# Epoch 15/50
# 30/30 - 2s - loss: 0.5926 - accuracy: 0.7678 - val_loss: 0.6097 - val_accuracy: 0.7831
#
# Epoch 00015: val_accuracy did not improve from 0.85708
# Epoch 16/50
# 30/30 - 2s - loss: 0.5653 - accuracy: 0.7790 - val_loss: 0.6769 - val_accuracy: 0.7394
#
# Epoch 00016: val_accuracy did not improve from 0.85708
# Epoch 17/50
# 30/30 - 2s - loss: 0.5314 - accuracy: 0.7982 - val_loss: 0.5980 - val_accuracy: 0.7656
#
# Epoch 00017: val_accuracy did not improve from 0.85708
# Epoch 18/50
# 30/30 - 2s - loss: 0.5154 - accuracy: 0.8013 - val_loss: 0.5978 - val_accuracy: 0.7656
#
# Epoch 00018: val_accuracy did not improve from 0.85708
# Epoch 19/50
# 30/30 - 2s - loss: 0.4946 - accuracy: 0.8084 - val_loss: 0.6228 - val_accuracy: 0.7403
#
# Epoch 00019: val_accuracy did not improve from 0.85708
# Epoch 20/50
# 30/30 - 2s - loss: 0.4666 - accuracy: 0.8229 - val_loss: 0.5888 - val_accuracy: 0.7638
#
# Epoch 00020: val_accuracy did not improve from 0.85708
# Epoch 21/50
# 30/30 - 2s - loss: 0.4525 - accuracy: 0.8293 - val_loss: 0.5380 - val_accuracy: 0.8043
#
# Epoch 00021: val_accuracy did not improve from 0.85708
# Epoch 22/50
# 30/30 - 2s - loss: 0.4303 - accuracy: 0.8424 - val_loss: 0.5579 - val_accuracy: 0.7845
#
# Epoch 00022: val_accuracy did not improve from 0.85708
# Epoch 23/50
# 30/30 - 2s - loss: 0.4160 - accuracy: 0.8494 - val_loss: 0.5125 - val_accuracy: 0.8233
#
# Epoch 00023: val_accuracy did not improve from 0.85708
# Epoch 24/50
# 30/30 - 2s - loss: 0.4057 - accuracy: 0.8491 - val_loss: 0.5129 - val_accuracy: 0.8201
#
# Epoch 00024: val_accuracy did not improve from 0.85708
# Epoch 25/50
# 30/30 - 2s - loss: 0.3984 - accuracy: 0.8570 - val_loss: 0.5747 - val_accuracy: 0.7931
#
# Epoch 00025: val_accuracy did not improve from 0.85708
# Epoch 26/50
# 30/30 - 2s - loss: 0.3758 - accuracy: 0.8678 - val_loss: 0.5181 - val_accuracy: 0.8215
#
# Epoch 00026: val_accuracy did not improve from 0.85708
# Epoch 27/50
# 30/30 - 2s - loss: 0.3687 - accuracy: 0.8673 - val_loss: 0.5452 - val_accuracy: 0.8088
#
# Epoch 00027: val_accuracy did not improve from 0.85708
# Epoch 28/50
# 30/30 - 2s - loss: 0.3565 - accuracy: 0.8770 - val_loss: 0.5171 - val_accuracy: 0.8251
#
# Epoch 00028: val_accuracy did not improve from 0.85708
# Epoch 29/50
# 30/30 - 2s - loss: 0.3516 - accuracy: 0.8758 - val_loss: 0.5924 - val_accuracy: 0.7931
#
# Epoch 00029: val_accuracy did not improve from 0.85708
# Epoch 30/50
# 30/30 - 2s - loss: 0.3404 - accuracy: 0.8805 - val_loss: 0.5085 - val_accuracy: 0.8228
#
# Epoch 00030: val_accuracy did not improve from 0.85708
# Epoch 31/50
# 30/30 - 2s - loss: 0.3370 - accuracy: 0.8819 - val_loss: 0.6379 - val_accuracy: 0.7583
#
# Epoch 00031: val_accuracy did not improve from 0.85708
# Epoch 32/50
# 30/30 - 2s - loss: 0.3257 - accuracy: 0.8875 - val_loss: 0.4988 - val_accuracy: 0.8377
#
# Epoch 00032: val_accuracy did not improve from 0.85708
# Epoch 33/50
# 30/30 - 2s - loss: 0.3200 - accuracy: 0.8915 - val_loss: 0.5088 - val_accuracy: 0.8404
#
# Epoch 00033: val_accuracy did not improve from 0.85708
# Epoch 34/50
# 30/30 - 2s - loss: 0.3078 - accuracy: 0.8948 - val_loss: 0.5535 - val_accuracy: 0.8233
#
# Epoch 00034: val_accuracy did not improve from 0.85708
# Epoch 35/50
# 30/30 - 2s - loss: 0.3091 - accuracy: 0.8959 - val_loss: 0.5421 - val_accuracy: 0.8282
#
# Epoch 00035: val_accuracy did not improve from 0.85708
# Epoch 36/50
# 30/30 - 2s - loss: 0.2892 - accuracy: 0.9029 - val_loss: 0.5238 - val_accuracy: 0.8427
#
# Epoch 00036: val_accuracy did not improve from 0.85708
# Epoch 37/50
# 30/30 - 2s - loss: 0.2983 - accuracy: 0.8969 - val_loss: 0.6355 - val_accuracy: 0.7953
#
# Epoch 00037: val_accuracy did not improve from 0.85708
# Epoch 38/50
# 30/30 - 2s - loss: 0.2940 - accuracy: 0.9025 - val_loss: 0.4973 - val_accuracy: 0.8449
#
# Epoch 00038: val_accuracy did not improve from 0.85708
# Epoch 39/50
# 30/30 - 2s - loss: 0.2816 - accuracy: 0.9067 - val_loss: 0.5641 - val_accuracy: 0.8061
#
# Epoch 00039: val_accuracy did not improve from 0.85708
# Epoch 40/50
# 30/30 - 2s - loss: 0.2847 - accuracy: 0.9040 - val_loss: 0.5418 - val_accuracy: 0.8174
#
# Epoch 00040: val_accuracy did not improve from 0.85708
# Epoch 41/50
# 30/30 - 2s - loss: 0.2781 - accuracy: 0.9091 - val_loss: 0.5536 - val_accuracy: 0.8323
#
# Epoch 00041: val_accuracy did not improve from 0.85708
# Epoch 42/50
# 30/30 - 2s - loss: 0.2692 - accuracy: 0.9107 - val_loss: 0.5465 - val_accuracy: 0.8386
#
# Epoch 00042: val_accuracy did not improve from 0.85708
# Epoch 43/50
# 30/30 - 2s - loss: 0.2616 - accuracy: 0.9178 - val_loss: 0.5504 - val_accuracy: 0.8440
#
# Epoch 00043: val_accuracy did not improve from 0.85708
# Epoch 44/50
# 30/30 - 2s - loss: 0.2578 - accuracy: 0.9161 - val_loss: 0.6123 - val_accuracy: 0.8228
#
# Epoch 00044: val_accuracy did not improve from 0.85708
# Epoch 45/50
# 30/30 - 2s - loss: 0.2552 - accuracy: 0.9162 - val_loss: 0.5670 - val_accuracy: 0.8399
#
# Epoch 00045: val_accuracy did not improve from 0.85708
# Epoch 46/50
# 30/30 - 2s - loss: 0.2615 - accuracy: 0.9125 - val_loss: 0.5621 - val_accuracy: 0.8413
#
# Epoch 00046: val_accuracy did not improve from 0.85708
# Epoch 47/50
# 30/30 - 2s - loss: 0.2495 - accuracy: 0.9212 - val_loss: 0.5269 - val_accuracy: 0.8526
#
# Epoch 00047: val_accuracy did not improve from 0.85708
# Epoch 48/50
# 30/30 - 2s - loss: 0.2396 - accuracy: 0.9259 - val_loss: 0.5521 - val_accuracy: 0.8449
#
# Epoch 00048: val_accuracy did not improve from 0.85708
# Epoch 49/50
# 30/30 - 2s - loss: 0.2388 - accuracy: 0.9278 - val_loss: 0.7579 - val_accuracy: 0.7890
#
# Epoch 00049: val_accuracy did not improve from 0.85708
# Epoch 50/50
# 30/30 - 2s - loss: 0.2493 - accuracy: 0.9201 - val_loss: 0.5745 - val_accuracy: 0.8408
#
# Epoch 00050: val_accuracy did not improve from 0.85708
# accuracy: 84.08%
# Epoch 1/50
# 30/30 - 9s - loss: 1.2771 - accuracy: 0.4691 - val_loss: 1.2484 - val_accuracy: 0.4815
#
# Epoch 00001: val_accuracy did not improve from 0.85708
# Epoch 2/50
# 30/30 - 2s - loss: 1.2296 - accuracy: 0.4768 - val_loss: 1.2154 - val_accuracy: 0.4815
#
# Epoch 00002: val_accuracy did not improve from 0.85708
# Epoch 3/50
# 30/30 - 2s - loss: 1.2037 - accuracy: 0.4768 - val_loss: 1.1878 - val_accuracy: 0.4815
#
# Epoch 00003: val_accuracy did not improve from 0.85708
# Epoch 4/50
# 30/30 - 2s - loss: 1.1710 - accuracy: 0.4770 - val_loss: 1.1542 - val_accuracy: 0.4815
#
# Epoch 00004: val_accuracy did not improve from 0.85708
# Epoch 5/50
# 30/30 - 2s - loss: 1.1390 - accuracy: 0.4854 - val_loss: 1.1230 - val_accuracy: 0.5059
#
# Epoch 00005: val_accuracy did not improve from 0.85708
# Epoch 6/50
# 30/30 - 2s - loss: 1.0997 - accuracy: 0.5215 - val_loss: 1.0777 - val_accuracy: 0.5478
#
# Epoch 00006: val_accuracy did not improve from 0.85708
# Epoch 7/50
# 30/30 - 2s - loss: 1.0438 - accuracy: 0.5632 - val_loss: 1.0177 - val_accuracy: 0.5906
#
# Epoch 00007: val_accuracy did not improve from 0.85708
# Epoch 8/50
# 30/30 - 2s - loss: 0.9774 - accuracy: 0.6104 - val_loss: 0.9533 - val_accuracy: 0.6235
#
# Epoch 00008: val_accuracy did not improve from 0.85708
# Epoch 9/50
# 30/30 - 2s - loss: 0.9153 - accuracy: 0.6387 - val_loss: 0.8824 - val_accuracy: 0.6605
#
# Epoch 00009: val_accuracy did not improve from 0.85708
# Epoch 10/50
# 30/30 - 2s - loss: 0.8492 - accuracy: 0.6674 - val_loss: 0.8301 - val_accuracy: 0.6722
#
# Epoch 00010: val_accuracy did not improve from 0.85708
# Epoch 11/50
# 30/30 - 2s - loss: 0.8024 - accuracy: 0.6821 - val_loss: 0.7828 - val_accuracy: 0.6948
#
# Epoch 00011: val_accuracy did not improve from 0.85708
# Epoch 12/50
# 30/30 - 2s - loss: 0.7562 - accuracy: 0.6997 - val_loss: 0.7528 - val_accuracy: 0.7083
#
# Epoch 00012: val_accuracy did not improve from 0.85708
# Epoch 13/50
# 30/30 - 2s - loss: 0.7122 - accuracy: 0.7169 - val_loss: 0.7151 - val_accuracy: 0.7227
#
# Epoch 00013: val_accuracy did not improve from 0.85708
# Epoch 14/50
# 30/30 - 2s - loss: 0.6719 - accuracy: 0.7361 - val_loss: 0.7327 - val_accuracy: 0.7065
#
# Epoch 00014: val_accuracy did not improve from 0.85708
# Epoch 15/50
# 30/30 - 2s - loss: 0.6428 - accuracy: 0.7446 - val_loss: 0.6925 - val_accuracy: 0.7106
#
# Epoch 00015: val_accuracy did not improve from 0.85708
# Epoch 16/50
# 30/30 - 2s - loss: 0.6137 - accuracy: 0.7604 - val_loss: 0.6402 - val_accuracy: 0.7471
#
# Epoch 00016: val_accuracy did not improve from 0.85708
# Epoch 17/50
# 30/30 - 2s - loss: 0.5831 - accuracy: 0.7730 - val_loss: 0.6612 - val_accuracy: 0.7182
#
# Epoch 00017: val_accuracy did not improve from 0.85708
# Epoch 18/50
# 30/30 - 2s - loss: 0.5606 - accuracy: 0.7820 - val_loss: 0.6051 - val_accuracy: 0.7588
#
# Epoch 00018: val_accuracy did not improve from 0.85708
# Epoch 19/50
# 30/30 - 2s - loss: 0.5335 - accuracy: 0.7912 - val_loss: 0.5898 - val_accuracy: 0.7628
#
# Epoch 00019: val_accuracy did not improve from 0.85708
# Epoch 20/50
# 30/30 - 2s - loss: 0.5129 - accuracy: 0.8018 - val_loss: 0.6295 - val_accuracy: 0.7385
#
# Epoch 00020: val_accuracy did not improve from 0.85708
# Epoch 21/50
# 30/30 - 2s - loss: 0.4873 - accuracy: 0.8144 - val_loss: 0.6177 - val_accuracy: 0.7430
#
# Epoch 00021: val_accuracy did not improve from 0.85708
# Epoch 22/50
# 30/30 - 2s - loss: 0.4833 - accuracy: 0.8130 - val_loss: 0.5559 - val_accuracy: 0.7813
#
# Epoch 00022: val_accuracy did not improve from 0.85708
# Epoch 23/50
# 30/30 - 2s - loss: 0.4558 - accuracy: 0.8311 - val_loss: 0.5678 - val_accuracy: 0.7723
#
# Epoch 00023: val_accuracy did not improve from 0.85708
# Epoch 24/50
# 30/30 - 2s - loss: 0.4403 - accuracy: 0.8346 - val_loss: 0.6352 - val_accuracy: 0.7335
#
# Epoch 00024: val_accuracy did not improve from 0.85708
# Epoch 25/50
# 30/30 - 2s - loss: 0.4236 - accuracy: 0.8448 - val_loss: 0.5058 - val_accuracy: 0.8156
#
# Epoch 00025: val_accuracy did not improve from 0.85708
# Epoch 26/50
# 30/30 - 2s - loss: 0.4181 - accuracy: 0.8441 - val_loss: 0.5127 - val_accuracy: 0.8111
#
# Epoch 00026: val_accuracy did not improve from 0.85708
# Epoch 27/50
# 30/30 - 2s - loss: 0.3969 - accuracy: 0.8576 - val_loss: 0.5610 - val_accuracy: 0.7827
#
# Epoch 00027: val_accuracy did not improve from 0.85708
# Epoch 28/50
# 30/30 - 2s - loss: 0.3878 - accuracy: 0.8577 - val_loss: 0.5735 - val_accuracy: 0.7732
#
# Epoch 00028: val_accuracy did not improve from 0.85708
# Epoch 29/50
# 30/30 - 2s - loss: 0.3697 - accuracy: 0.8684 - val_loss: 0.8251 - val_accuracy: 0.7169
#
# Epoch 00029: val_accuracy did not improve from 0.85708
# Epoch 30/50
# 30/30 - 2s - loss: 0.3827 - accuracy: 0.8617 - val_loss: 0.5799 - val_accuracy: 0.7908
#
# Epoch 00030: val_accuracy did not improve from 0.85708
# Epoch 31/50
# 30/30 - 2s - loss: 0.3510 - accuracy: 0.8762 - val_loss: 0.8873 - val_accuracy: 0.7065
#
# Epoch 00031: val_accuracy did not improve from 0.85708
# Epoch 32/50
# 30/30 - 2s - loss: 0.3618 - accuracy: 0.8750 - val_loss: 0.5004 - val_accuracy: 0.8233
#
# Epoch 00032: val_accuracy did not improve from 0.85708
# Epoch 33/50
# 30/30 - 2s - loss: 0.3456 - accuracy: 0.8776 - val_loss: 0.5381 - val_accuracy: 0.8057
#
# Epoch 00033: val_accuracy did not improve from 0.85708
# Epoch 34/50
# 30/30 - 2s - loss: 0.3367 - accuracy: 0.8826 - val_loss: 0.4894 - val_accuracy: 0.8332
#
# Epoch 00034: val_accuracy did not improve from 0.85708
# Epoch 35/50
# 30/30 - 2s - loss: 0.3318 - accuracy: 0.8844 - val_loss: 0.5460 - val_accuracy: 0.8156
#
# Epoch 00035: val_accuracy did not improve from 0.85708
# Epoch 36/50
# 30/30 - 2s - loss: 0.3221 - accuracy: 0.8904 - val_loss: 0.5150 - val_accuracy: 0.8305
#
# Epoch 00036: val_accuracy did not improve from 0.85708
# Epoch 37/50
# 30/30 - 2s - loss: 0.3136 - accuracy: 0.8917 - val_loss: 0.5434 - val_accuracy: 0.8215
#
# Epoch 00037: val_accuracy did not improve from 0.85708
# Epoch 38/50
# 30/30 - 2s - loss: 0.3059 - accuracy: 0.8959 - val_loss: 0.6021 - val_accuracy: 0.8012
#
# Epoch 00038: val_accuracy did not improve from 0.85708
# Epoch 39/50
# 30/30 - 2s - loss: 0.3072 - accuracy: 0.8940 - val_loss: 0.5840 - val_accuracy: 0.8115
#
# Epoch 00039: val_accuracy did not improve from 0.85708
# Epoch 40/50
# 30/30 - 2s - loss: 0.2936 - accuracy: 0.9055 - val_loss: 0.5471 - val_accuracy: 0.8296
#
# Epoch 00040: val_accuracy did not improve from 0.85708
# Epoch 41/50
# 30/30 - 2s - loss: 0.2880 - accuracy: 0.9020 - val_loss: 0.6113 - val_accuracy: 0.8057
#
# Epoch 00041: val_accuracy did not improve from 0.85708
# Epoch 42/50
# 30/30 - 2s - loss: 0.2843 - accuracy: 0.9039 - val_loss: 0.5192 - val_accuracy: 0.8404
#
# Epoch 00042: val_accuracy did not improve from 0.85708
# Epoch 43/50
# 30/30 - 2s - loss: 0.2793 - accuracy: 0.9069 - val_loss: 0.6159 - val_accuracy: 0.8070
#
# Epoch 00043: val_accuracy did not improve from 0.85708
# Epoch 44/50
# 30/30 - 2s - loss: 0.2789 - accuracy: 0.9080 - val_loss: 0.5298 - val_accuracy: 0.8363
#
# Epoch 00044: val_accuracy did not improve from 0.85708
# Epoch 45/50
# 30/30 - 2s - loss: 0.2593 - accuracy: 0.9155 - val_loss: 0.6260 - val_accuracy: 0.8106
#
# Epoch 00045: val_accuracy did not improve from 0.85708
# Epoch 46/50
# 30/30 - 2s - loss: 0.2515 - accuracy: 0.9224 - val_loss: 0.5225 - val_accuracy: 0.8467
#
# Epoch 00046: val_accuracy did not improve from 0.85708
# Epoch 47/50
# 30/30 - 2s - loss: 0.2693 - accuracy: 0.9113 - val_loss: 0.6349 - val_accuracy: 0.8120
#
# Epoch 00047: val_accuracy did not improve from 0.85708
# Epoch 48/50
# 30/30 - 2s - loss: 0.2557 - accuracy: 0.9167 - val_loss: 0.6283 - val_accuracy: 0.7908
#
# Epoch 00048: val_accuracy did not improve from 0.85708
# Epoch 49/50
# 30/30 - 2s - loss: 0.2434 - accuracy: 0.9236 - val_loss: 0.5655 - val_accuracy: 0.8445
#
# Epoch 00049: val_accuracy did not improve from 0.85708
# Epoch 50/50
# 30/30 - 2s - loss: 0.2405 - accuracy: 0.9252 - val_loss: 0.5211 - val_accuracy: 0.8499
#
# Epoch 00050: val_accuracy did not improve from 0.85708
# accuracy: 84.99%
# Epoch 1/50
# 30/30 - 9s - loss: 1.2760 - accuracy: 0.4685 - val_loss: 1.2456 - val_accuracy: 0.4815
#
# Epoch 00001: val_accuracy did not improve from 0.85708
# Epoch 2/50
# 30/30 - 2s - loss: 1.2300 - accuracy: 0.4768 - val_loss: 1.2147 - val_accuracy: 0.4815
#
# Epoch 00002: val_accuracy did not improve from 0.85708
# Epoch 3/50
# 30/30 - 2s - loss: 1.2031 - accuracy: 0.4768 - val_loss: 1.1861 - val_accuracy: 0.4815
#
# Epoch 00003: val_accuracy did not improve from 0.85708
# Epoch 4/50
# 30/30 - 2s - loss: 1.1692 - accuracy: 0.4771 - val_loss: 1.1527 - val_accuracy: 0.4815
#
# Epoch 00004: val_accuracy did not improve from 0.85708
# Epoch 5/50
# 30/30 - 2s - loss: 1.1385 - accuracy: 0.4875 - val_loss: 1.1234 - val_accuracy: 0.5117
#
# Epoch 00005: val_accuracy did not improve from 0.85708
# Epoch 6/50
# 30/30 - 2s - loss: 1.1033 - accuracy: 0.5228 - val_loss: 1.0813 - val_accuracy: 0.5419
#
# Epoch 00006: val_accuracy did not improve from 0.85708
# Epoch 7/50
# 30/30 - 2s - loss: 1.0526 - accuracy: 0.5638 - val_loss: 1.0199 - val_accuracy: 0.6091
#
# Epoch 00007: val_accuracy did not improve from 0.85708
# Epoch 8/50
# 30/30 - 2s - loss: 0.9844 - accuracy: 0.6141 - val_loss: 0.9710 - val_accuracy: 0.6073
#
# Epoch 00008: val_accuracy did not improve from 0.85708
# Epoch 9/50
# 30/30 - 2s - loss: 0.9130 - accuracy: 0.6486 - val_loss: 0.8801 - val_accuracy: 0.6677
#
# Epoch 00009: val_accuracy did not improve from 0.85708
# Epoch 10/50
# 30/30 - 2s - loss: 0.8499 - accuracy: 0.6704 - val_loss: 0.8210 - val_accuracy: 0.6867
#
# Epoch 00010: val_accuracy did not improve from 0.85708
# Epoch 11/50
# 30/30 - 2s - loss: 0.7958 - accuracy: 0.6862 - val_loss: 0.7796 - val_accuracy: 0.7006
#
# Epoch 00011: val_accuracy did not improve from 0.85708
# Epoch 12/50
# 30/30 - 2s - loss: 0.7507 - accuracy: 0.7019 - val_loss: 0.7502 - val_accuracy: 0.7074
#
# Epoch 00012: val_accuracy did not improve from 0.85708
# Epoch 13/50
# 30/30 - 2s - loss: 0.7091 - accuracy: 0.7206 - val_loss: 0.7053 - val_accuracy: 0.7349
#
# Epoch 00013: val_accuracy did not improve from 0.85708
# Epoch 14/50
# 30/30 - 2s - loss: 0.6722 - accuracy: 0.7400 - val_loss: 0.7482 - val_accuracy: 0.6709
#
# Epoch 00014: val_accuracy did not improve from 0.85708
# Epoch 15/50
# 30/30 - 2s - loss: 0.6367 - accuracy: 0.7497 - val_loss: 0.6971 - val_accuracy: 0.6988
#
# Epoch 00015: val_accuracy did not improve from 0.85708
# Epoch 16/50
# 30/30 - 2s - loss: 0.6055 - accuracy: 0.7657 - val_loss: 0.6664 - val_accuracy: 0.7155
#
# Epoch 00016: val_accuracy did not improve from 0.85708
# Epoch 17/50
# 30/30 - 2s - loss: 0.5820 - accuracy: 0.7751 - val_loss: 0.7304 - val_accuracy: 0.6709
#
# Epoch 00017: val_accuracy did not improve from 0.85708
# Epoch 18/50
# 30/30 - 2s - loss: 0.5521 - accuracy: 0.7892 - val_loss: 0.6925 - val_accuracy: 0.6952
#
# Epoch 00018: val_accuracy did not improve from 0.85708
# Epoch 19/50
# 30/30 - 2s - loss: 0.5336 - accuracy: 0.7975 - val_loss: 0.6147 - val_accuracy: 0.7412
#
# Epoch 00019: val_accuracy did not improve from 0.85708
# Epoch 20/50
# 30/30 - 2s - loss: 0.5067 - accuracy: 0.8087 - val_loss: 0.5923 - val_accuracy: 0.7552
#
# Epoch 00020: val_accuracy did not improve from 0.85708
# Epoch 21/50
# 30/30 - 2s - loss: 0.4881 - accuracy: 0.8164 - val_loss: 0.5953 - val_accuracy: 0.7480
#
# Epoch 00021: val_accuracy did not improve from 0.85708
# Epoch 22/50
# 30/30 - 2s - loss: 0.4724 - accuracy: 0.8227 - val_loss: 0.5844 - val_accuracy: 0.7570
#
# Epoch 00022: val_accuracy did not improve from 0.85708
# Epoch 23/50
# 30/30 - 2s - loss: 0.4519 - accuracy: 0.8337 - val_loss: 0.5186 - val_accuracy: 0.8142
#
# Epoch 00023: val_accuracy did not improve from 0.85708
# Epoch 24/50
# 30/30 - 2s - loss: 0.4319 - accuracy: 0.8450 - val_loss: 0.6099 - val_accuracy: 0.7448
#
# Epoch 00024: val_accuracy did not improve from 0.85708
# Epoch 25/50
# 30/30 - 2s - loss: 0.4337 - accuracy: 0.8373 - val_loss: 0.5460 - val_accuracy: 0.7854
#
# Epoch 00025: val_accuracy did not improve from 0.85708
# Epoch 26/50
# 30/30 - 2s - loss: 0.4083 - accuracy: 0.8546 - val_loss: 0.5003 - val_accuracy: 0.8287
#
# Epoch 00026: val_accuracy did not improve from 0.85708
# Epoch 27/50
# 30/30 - 2s - loss: 0.3983 - accuracy: 0.8558 - val_loss: 0.5070 - val_accuracy: 0.8336
#
# Epoch 00027: val_accuracy did not improve from 0.85708
# Epoch 28/50
# 30/30 - 2s - loss: 0.3854 - accuracy: 0.8649 - val_loss: 0.5271 - val_accuracy: 0.8012
#
# Epoch 00028: val_accuracy did not improve from 0.85708
# Epoch 29/50
# 30/30 - 2s - loss: 0.3748 - accuracy: 0.8682 - val_loss: 0.6290 - val_accuracy: 0.7444
#
# Epoch 00029: val_accuracy did not improve from 0.85708
# Epoch 30/50
# 30/30 - 2s - loss: 0.3593 - accuracy: 0.8763 - val_loss: 0.4864 - val_accuracy: 0.8458
#
# Epoch 00030: val_accuracy did not improve from 0.85708
# Epoch 31/50
# 30/30 - 2s - loss: 0.3498 - accuracy: 0.8808 - val_loss: 0.5818 - val_accuracy: 0.7885
#
# Epoch 00031: val_accuracy did not improve from 0.85708
# Epoch 32/50
# 30/30 - 2s - loss: 0.3411 - accuracy: 0.8846 - val_loss: 0.5217 - val_accuracy: 0.8309
#
# Epoch 00032: val_accuracy did not improve from 0.85708
# Epoch 33/50
# 30/30 - 2s - loss: 0.3417 - accuracy: 0.8829 - val_loss: 0.5279 - val_accuracy: 0.8296
#
# Epoch 00033: val_accuracy did not improve from 0.85708
# Epoch 34/50
# 30/30 - 2s - loss: 0.3228 - accuracy: 0.8943 - val_loss: 0.5061 - val_accuracy: 0.8408
#
# Epoch 00034: val_accuracy did not improve from 0.85708
# Epoch 35/50
# 30/30 - 2s - loss: 0.3209 - accuracy: 0.8913 - val_loss: 0.5941 - val_accuracy: 0.7958
#
# Epoch 00035: val_accuracy did not improve from 0.85708
# Epoch 36/50
# 30/30 - 2s - loss: 0.3073 - accuracy: 0.9001 - val_loss: 0.4899 - val_accuracy: 0.8499
#
# Epoch 00036: val_accuracy did not improve from 0.85708
# Epoch 37/50
# 30/30 - 2s - loss: 0.3073 - accuracy: 0.8952 - val_loss: 0.5002 - val_accuracy: 0.8517
#
# Epoch 00037: val_accuracy did not improve from 0.85708
# Epoch 38/50
# 30/30 - 2s - loss: 0.2929 - accuracy: 0.9068 - val_loss: 0.4910 - val_accuracy: 0.8517
#
# Epoch 00038: val_accuracy did not improve from 0.85708
# Epoch 39/50
# 30/30 - 2s - loss: 0.2958 - accuracy: 0.9042 - val_loss: 0.4907 - val_accuracy: 0.8463
#
# Epoch 00039: val_accuracy did not improve from 0.85708
# Epoch 40/50
# 30/30 - 2s - loss: 0.2791 - accuracy: 0.9116 - val_loss: 0.4916 - val_accuracy: 0.8481
#
# Epoch 00040: val_accuracy did not improve from 0.85708
# Epoch 41/50
# 30/30 - 2s - loss: 0.2794 - accuracy: 0.9088 - val_loss: 0.5443 - val_accuracy: 0.8354
#
# Epoch 00041: val_accuracy did not improve from 0.85708
# Epoch 42/50
# 30/30 - 2s - loss: 0.2756 - accuracy: 0.9143 - val_loss: 0.5655 - val_accuracy: 0.8305
#
# Epoch 00042: val_accuracy did not improve from 0.85708
# Epoch 43/50
# 30/30 - 2s - loss: 0.2730 - accuracy: 0.9133 - val_loss: 0.5182 - val_accuracy: 0.8503
#
# Epoch 00043: val_accuracy did not improve from 0.85708
# Epoch 44/50
# 30/30 - 2s - loss: 0.2558 - accuracy: 0.9217 - val_loss: 0.5238 - val_accuracy: 0.8503
#
# Epoch 00044: val_accuracy did not improve from 0.85708
# Epoch 45/50
# 30/30 - 2s - loss: 0.2556 - accuracy: 0.9202 - val_loss: 0.5252 - val_accuracy: 0.8521
#
# Epoch 00045: val_accuracy did not improve from 0.85708
# Epoch 46/50
# 30/30 - 2s - loss: 0.2573 - accuracy: 0.9192 - val_loss: 0.5425 - val_accuracy: 0.8472
#
# Epoch 00046: val_accuracy did not improve from 0.85708
# Epoch 47/50
# 30/30 - 2s - loss: 0.2431 - accuracy: 0.9273 - val_loss: 0.5310 - val_accuracy: 0.8332
#
# Epoch 00047: val_accuracy did not improve from 0.85708
# Epoch 48/50
# 30/30 - 2s - loss: 0.2408 - accuracy: 0.9265 - val_loss: 0.6217 - val_accuracy: 0.8016
#
# Epoch 00048: val_accuracy did not improve from 0.85708
# Epoch 49/50
# 30/30 - 2s - loss: 0.2452 - accuracy: 0.9229 - val_loss: 0.5502 - val_accuracy: 0.8264
#
# Epoch 00049: val_accuracy did not improve from 0.85708
# Epoch 50/50
# 30/30 - 2s - loss: 0.2265 - accuracy: 0.9320 - val_loss: 0.5533 - val_accuracy: 0.8300
#
# Epoch 00050: val_accuracy did not improve from 0.85708
# accuracy: 83.00%
# Epoch 1/50
# 30/30 - 9s - loss: 1.2769 - accuracy: 0.4702 - val_loss: 1.2460 - val_accuracy: 0.4815
#
# Epoch 00001: val_accuracy did not improve from 0.85708
# Epoch 2/50
# 30/30 - 2s - loss: 1.2259 - accuracy: 0.4768 - val_loss: 1.2051 - val_accuracy: 0.4815
#
# Epoch 00002: val_accuracy did not improve from 0.85708
# Epoch 3/50
# 30/30 - 2s - loss: 1.1849 - accuracy: 0.4770 - val_loss: 1.1650 - val_accuracy: 0.4815
#
# Epoch 00003: val_accuracy did not improve from 0.85708
# Epoch 4/50
# 30/30 - 2s - loss: 1.1501 - accuracy: 0.4922 - val_loss: 1.1338 - val_accuracy: 0.5144
#
# Epoch 00004: val_accuracy did not improve from 0.85708
# Epoch 5/50
# 30/30 - 2s - loss: 1.1100 - accuracy: 0.5285 - val_loss: 1.0839 - val_accuracy: 0.5568
#
# Epoch 00005: val_accuracy did not improve from 0.85708
# Epoch 6/50
# 30/30 - 2s - loss: 1.0489 - accuracy: 0.5758 - val_loss: 1.0118 - val_accuracy: 0.6078
#
# Epoch 00006: val_accuracy did not improve from 0.85708
# Epoch 7/50
# 30/30 - 2s - loss: 0.9708 - accuracy: 0.6234 - val_loss: 0.9972 - val_accuracy: 0.5830
#
# Epoch 00007: val_accuracy did not improve from 0.85708
# Epoch 8/50
# 30/30 - 2s - loss: 0.9000 - accuracy: 0.6510 - val_loss: 0.8680 - val_accuracy: 0.6655
#
# Epoch 00008: val_accuracy did not improve from 0.85708
# Epoch 9/50
# 30/30 - 2s - loss: 0.8361 - accuracy: 0.6754 - val_loss: 0.8165 - val_accuracy: 0.6849
#
# Epoch 00009: val_accuracy did not improve from 0.85708
# Epoch 10/50
# 30/30 - 2s - loss: 0.7842 - accuracy: 0.6910 - val_loss: 0.7702 - val_accuracy: 0.7033
#
# Epoch 00010: val_accuracy did not improve from 0.85708
# Epoch 11/50
# 30/30 - 2s - loss: 0.7413 - accuracy: 0.7116 - val_loss: 0.7346 - val_accuracy: 0.7254
#
# Epoch 00011: val_accuracy did not improve from 0.85708
# Epoch 12/50
# 30/30 - 2s - loss: 0.6990 - accuracy: 0.7313 - val_loss: 0.7226 - val_accuracy: 0.7074
#
# Epoch 00012: val_accuracy did not improve from 0.85708
# Epoch 13/50
# 30/30 - 2s - loss: 0.6644 - accuracy: 0.7424 - val_loss: 0.8125 - val_accuracy: 0.6528
#
# Epoch 00013: val_accuracy did not improve from 0.85708
# Epoch 14/50
# 30/30 - 2s - loss: 0.6295 - accuracy: 0.7600 - val_loss: 0.7271 - val_accuracy: 0.6970
#
# Epoch 00014: val_accuracy did not improve from 0.85708
# Epoch 15/50
# 30/30 - 2s - loss: 0.6025 - accuracy: 0.7720 - val_loss: 0.7368 - val_accuracy: 0.6925
#
# Epoch 00015: val_accuracy did not improve from 0.85708
# Epoch 16/50
# 30/30 - 2s - loss: 0.5679 - accuracy: 0.7880 - val_loss: 0.7574 - val_accuracy: 0.6803
#
# Epoch 00016: val_accuracy did not improve from 0.85708
# Epoch 17/50
# 30/30 - 2s - loss: 0.5544 - accuracy: 0.7885 - val_loss: 0.6521 - val_accuracy: 0.7367
#
# Epoch 00017: val_accuracy did not improve from 0.85708
# Epoch 18/50
# 30/30 - 2s - loss: 0.5346 - accuracy: 0.7971 - val_loss: 0.6603 - val_accuracy: 0.7340
#
# Epoch 00018: val_accuracy did not improve from 0.85708
# Epoch 19/50
# 30/30 - 2s - loss: 0.5032 - accuracy: 0.8119 - val_loss: 0.6600 - val_accuracy: 0.7304
#
# Epoch 00019: val_accuracy did not improve from 0.85708
# Epoch 20/50
# 30/30 - 2s - loss: 0.4812 - accuracy: 0.8260 - val_loss: 0.6719 - val_accuracy: 0.7263
#
# Epoch 00020: val_accuracy did not improve from 0.85708
# Epoch 21/50
# 30/30 - 2s - loss: 0.4758 - accuracy: 0.8219 - val_loss: 0.5854 - val_accuracy: 0.7773
#
# Epoch 00021: val_accuracy did not improve from 0.85708
# Epoch 22/50
# 30/30 - 2s - loss: 0.4458 - accuracy: 0.8413 - val_loss: 0.5526 - val_accuracy: 0.8016
#
# Epoch 00022: val_accuracy did not improve from 0.85708
# Epoch 23/50
# 30/30 - 2s - loss: 0.4341 - accuracy: 0.8423 - val_loss: 0.5338 - val_accuracy: 0.8179
#
# Epoch 00023: val_accuracy did not improve from 0.85708
# Epoch 24/50
# 30/30 - 2s - loss: 0.4290 - accuracy: 0.8418 - val_loss: 0.5355 - val_accuracy: 0.8151
#
# Epoch 00024: val_accuracy did not improve from 0.85708
# Epoch 25/50
# 30/30 - 2s - loss: 0.4064 - accuracy: 0.8560 - val_loss: 0.5401 - val_accuracy: 0.8161
#
# Epoch 00025: val_accuracy did not improve from 0.85708
# Epoch 26/50
# 30/30 - 2s - loss: 0.3919 - accuracy: 0.8637 - val_loss: 0.5468 - val_accuracy: 0.8003
#
# Epoch 00026: val_accuracy did not improve from 0.85708
# Epoch 27/50
# 30/30 - 2s - loss: 0.3918 - accuracy: 0.8635 - val_loss: 0.5426 - val_accuracy: 0.8057
#
# Epoch 00027: val_accuracy did not improve from 0.85708
# Epoch 28/50
# 30/30 - 2s - loss: 0.3848 - accuracy: 0.8636 - val_loss: 0.6361 - val_accuracy: 0.7475
#
# Epoch 00028: val_accuracy did not improve from 0.85708
# Epoch 29/50
# 30/30 - 2s - loss: 0.3636 - accuracy: 0.8775 - val_loss: 0.6113 - val_accuracy: 0.7678
#
# Epoch 00029: val_accuracy did not improve from 0.85708
# Epoch 30/50
# 30/30 - 2s - loss: 0.3674 - accuracy: 0.8756 - val_loss: 0.5107 - val_accuracy: 0.8287
#
# Epoch 00030: val_accuracy did not improve from 0.85708
# Epoch 31/50
# 30/30 - 2s - loss: 0.3424 - accuracy: 0.8858 - val_loss: 0.5214 - val_accuracy: 0.8314
#
# Epoch 00031: val_accuracy did not improve from 0.85708
# Epoch 32/50
# 30/30 - 2s - loss: 0.3350 - accuracy: 0.8883 - val_loss: 0.5766 - val_accuracy: 0.8106
#
# Epoch 00032: val_accuracy did not improve from 0.85708
# Epoch 33/50
# 30/30 - 2s - loss: 0.3519 - accuracy: 0.8795 - val_loss: 0.5463 - val_accuracy: 0.8233
#
# Epoch 00033: val_accuracy did not improve from 0.85708
# Epoch 34/50
# 30/30 - 2s - loss: 0.3260 - accuracy: 0.8940 - val_loss: 0.5319 - val_accuracy: 0.8260
#
# Epoch 00034: val_accuracy did not improve from 0.85708
# Epoch 35/50
# 30/30 - 2s - loss: 0.3117 - accuracy: 0.8994 - val_loss: 0.5681 - val_accuracy: 0.8161
#
# Epoch 00035: val_accuracy did not improve from 0.85708
# Epoch 36/50
# 30/30 - 2s - loss: 0.3359 - accuracy: 0.8848 - val_loss: 0.5349 - val_accuracy: 0.8269
#
# Epoch 00036: val_accuracy did not improve from 0.85708
# Epoch 37/50
# 30/30 - 2s - loss: 0.3027 - accuracy: 0.9023 - val_loss: 0.6532 - val_accuracy: 0.7556
#
# Epoch 00037: val_accuracy did not improve from 0.85708
# Epoch 38/50
# 30/30 - 2s - loss: 0.3062 - accuracy: 0.8992 - val_loss: 0.5271 - val_accuracy: 0.8246
#
# Epoch 00038: val_accuracy did not improve from 0.85708
# Epoch 39/50
# 30/30 - 2s - loss: 0.2933 - accuracy: 0.9057 - val_loss: 0.6182 - val_accuracy: 0.7822
#
# Epoch 00039: val_accuracy did not improve from 0.85708
# Epoch 40/50
# 30/30 - 2s - loss: 0.2961 - accuracy: 0.9034 - val_loss: 0.6124 - val_accuracy: 0.7813
#
# Epoch 00040: val_accuracy did not improve from 0.85708
# Epoch 41/50
# 30/30 - 2s - loss: 0.2819 - accuracy: 0.9100 - val_loss: 0.5223 - val_accuracy: 0.8363
#
# Epoch 00041: val_accuracy did not improve from 0.85708
# Epoch 42/50
# 30/30 - 2s - loss: 0.2895 - accuracy: 0.9082 - val_loss: 0.5609 - val_accuracy: 0.8269
#
# Epoch 00042: val_accuracy did not improve from 0.85708
# Epoch 43/50
# 30/30 - 2s - loss: 0.2670 - accuracy: 0.9175 - val_loss: 0.5648 - val_accuracy: 0.8291
#
# Epoch 00043: val_accuracy did not improve from 0.85708
# Epoch 44/50
# 30/30 - 2s - loss: 0.2911 - accuracy: 0.9090 - val_loss: 0.5272 - val_accuracy: 0.8359
#
# Epoch 00044: val_accuracy did not improve from 0.85708
# Epoch 45/50
# 30/30 - 2s - loss: 0.2408 - accuracy: 0.9346 - val_loss: 0.5337 - val_accuracy: 0.8377
#
# Epoch 00045: val_accuracy did not improve from 0.85708
# Epoch 46/50
# 30/30 - 2s - loss: 0.2633 - accuracy: 0.9221 - val_loss: 0.5329 - val_accuracy: 0.8458
#
# Epoch 00046: val_accuracy did not improve from 0.85708
# Epoch 47/50
# 30/30 - 2s - loss: 0.2586 - accuracy: 0.9203 - val_loss: 0.5331 - val_accuracy: 0.8463
#
# Epoch 00047: val_accuracy did not improve from 0.85708
# Epoch 48/50
# 30/30 - 2s - loss: 0.2350 - accuracy: 0.9314 - val_loss: 0.7840 - val_accuracy: 0.7714
#
# Epoch 00048: val_accuracy did not improve from 0.85708
# Epoch 49/50
# 30/30 - 2s - loss: 0.2511 - accuracy: 0.9269 - val_loss: 0.6934 - val_accuracy: 0.7719
#
# Epoch 00049: val_accuracy did not improve from 0.85708
# Epoch 50/50
# 30/30 - 2s - loss: 0.2478 - accuracy: 0.9266 - val_loss: 0.5646 - val_accuracy: 0.8399
#
# Epoch 00050: val_accuracy did not improve from 0.85708
# accuracy: 83.99%
# 84.00% (+/- 0.63%)
